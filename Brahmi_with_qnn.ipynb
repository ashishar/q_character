# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishar/q_character/blob/main/Brahmi_with_qnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchvision
# !pip install qiskit-machine-learning
import importlib

# Check if torchvision is installed
try:
    importlib.import_module('torchvision')
    print("torchvision is already installed.")
except ImportError:
    print("torchvision is not installed. Installing...")
    # Install torchvision using pip
    try:
        import pip
        pip.main(['install', 'torchvision'])
        print("torchvision installed successfully.")
    except Exception as e:
        print("Error occurred while installing torchvision:", str(e))

# try:
#     importlib.import_module('qiskit')
#     print("qiskit is already installed.")
# except ImportError:
#     print("qiskit is not installed. Installing...")
#     # Install torchvision using pip
#     try:
#         import pip
#         pip.main(['install', 'qiskit'])
#         print("qiskit installed successfully.")
#     except Exception as e:
#         print("Error occurred while installing qiskit:", str(e))

# try:
#     importlib.import_module('qiskit_machine_learning')
#     print("qiskit-machine-learning is already installed.")
# except ImportError:
#     print("qiskit-machine-learning is not installed. Installing...")
#     # Install torchvision using pip
#     try:
#         import pip
#         pip.main(['install', 'qiskit-machine-learning'])
#         print("qiskit-machine-learning installed successfully.")
#     except Exception as e:
#         print("Error occurred while installing qiskit-machine-learning:", str(e))
# Out:
# torchvision is already installed.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Change directory to the desired location where the file is stored.
# %cd /content/drive/MyDrive/

# Import the file named quantum_circuit_simulator.py
import quantum_circuit_simulator
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
# prompt: I want to download devanagari character dataset from Kaggle.

#!pip install kaggle
#!mkdir -p ~/.kaggle
#!cp /content/drive/MyDrive/devanagari/kaggle.json ~/.kaggle/kaggle.json
#!kaggle datasets download --force -d rishianand/devanagari-character-set
# !unzip "/content/drive/My Drive/devanagari-character-set.zip" -d "/content/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/Images/Images/digit_7/56662.png
#   inflating: /content/data/Images/Images/digit_7/56663.png
#   inflating: /content/data/Images/Images/digit_7/56664.png
#   inflating: /content/data/Images/Images/digit_7/56665.png
#   inflating: /content/data/Images/Images/digit_7/56666.png
#   inflating: /content/data/Images/Images/digit_7/56667.png
#   inflating: /content/data/Images/Images/digit_7/56668.png
#   inflating: /content/data/Images/Images/digit_7/56669.png
#   inflating: /content/data/Images/Images/digit_7/56670.png
#   inflating: /content/data/Images/Images/digit_7/56671.png
#   inflating: /content/data/Images/Images/digit_7/56672.png
#   inflating: /content/data/Images/Images/digit_7/56673.png
#   inflating: /content/data/Images/Images/digit_7/56674.png
#   inflating: /content/data/Images/Images/digit_7/56675.png
#   inflating: /content/data/Images/Images/digit_7/56676.png
#   inflating: /content/data/Images/Images/digit_7/56677.png
#   inflating: /content/data/Images/Images/digit_7/56678.png
#   inflating: /content/data/Images/Images/digit_7/56679.png
#   inflating: /content/data/Images/Images/digit_7/56680.png
#   inflating: /content/data/Images/Images/digit_7/56681.png
#   inflating: /content/data/Images/Images/digit_7/56682.png
#   inflating: /content/data/Images/Images/digit_7/56683.png
#   inflating: /content/data/Images/Images/digit_7/56684.png
#   inflating: /content/data/Images/Images/digit_7/56685.png
#   inflating: /content/data/Images/Images/digit_7/56686.png
#   inflating: /content/data/Images/Images/digit_7/56687.png
#   inflating: /content/data/Images/Images/digit_7/56688.png
#   inflating: /content/data/Images/Images/digit_7/56689.png
#   inflating: /content/data/Images/Images/digit_7/56690.png
#   inflating: /content/data/Images/Images/digit_7/56691.png
#   inflating: /content/data/Images/Images/digit_7/5691.png
#   inflating: /content/data/Images/Images/digit_7/5692.png
#   inflating: /content/data/Images/Images/digit_7/5693.png
#   inflating: /content/data/Images/Images/digit_7/5694.png
#   inflating: /content/data/Images/Images/digit_7/5695.png
#   inflating: /content/data/Images/Images/digit_7/5696.png
#   inflating: /content/data/Images/Images/digit_7/5697.png
#   inflating: /content/data/Images/Images/digit_7/5698.png
#   inflating: /content/data/Images/Images/digit_7/5699.png
#   inflating: /content/data/Images/Images/digit_7/5700.png
#   inflating: /content/data/Images/Images/digit_7/5701.png
#   inflating: /content/data/Images/Images/digit_7/5702.png
#   inflating: /content/data/Images/Images/digit_7/5703.png
#   inflating: /content/data/Images/Images/digit_7/5704.png
#   inflating: /content/data/Images/Images/digit_7/5705.png
#   inflating: /content/data/Images/Images/digit_7/5706.png
#   inflating: /content/data/Images/Images/digit_7/5707.png
#   inflating: /content/data/Images/Images/digit_7/5708.png
#   inflating: /content/data/Images/Images/digit_7/5709.png
#   inflating: /content/data/Images/Images/digit_7/5710.png
#   inflating: /content/data/Images/Images/digit_7/5711.png
#   inflating: /content/data/Images/Images/digit_7/5712.png
#   inflating: /content/data/Images/Images/digit_7/5713.png
#   inflating: /content/data/Images/Images/digit_7/5714.png
#   inflating: /content/data/Images/Images/digit_7/5715.png
#   inflating: /content/data/Images/Images/digit_7/5716.png
#   inflating: /content/data/Images/Images/digit_7/5717.png
#   inflating: /content/data/Images/Images/digit_7/5718.png
#   inflating: /content/data/Images/Images/digit_7/5719.png
#   inflating: /content/data/Images/Images/digit_7/5720.png
#   inflating: /content/data/Images/Images/digit_7/5721.png
#   inflating: /content/data/Images/Images/digit_7/5722.png
#   inflating: /content/data/Images/Images/digit_7/5723.png
#   inflating: /content/data/Images/Images/digit_7/5724.png
#   inflating: /content/data/Images/Images/digit_7/5725.png
#   inflating: /content/data/Images/Images/digit_7/5726.png
#   inflating: /content/data/Images/Images/digit_7/5727.png
#   inflating: /content/data/Images/Images/digit_7/5728.png
#   inflating: /content/data/Images/Images/digit_7/5729.png
#   inflating: /content/data/Images/Images/digit_7/5730.png
#   inflating: /content/data/Images/Images/digit_7/5731.png
#   inflating: /content/data/Images/Images/digit_7/5732.png
#   inflating: /content/data/Images/Images/digit_7/5733.png
#   inflating: /content/data/Images/Images/digit_7/5734.png
#   inflating: /content/data/Images/Images/digit_7/5735.png
#   inflating: /content/data/Images/Images/digit_7/5736.png
#   inflating: /content/data/Images/Images/digit_7/5737.png
#   inflating: /content/data/Images/Images/digit_7/5738.png
#   inflating: /content/data/Images/Images/digit_7/5739.png
#   inflating: /content/data/Images/Images/digit_7/5740.png
#   inflating: /content/data/Images/Images/digit_7/5741.png
#   inflating: /content/data/Images/Images/digit_7/5742.png
#   inflating: /content/data/Images/Images/digit_7/5743.png
#   inflating: /content/data/Images/Images/digit_7/5744.png
#   inflating: /content/data/Images/Images/digit_7/5745.png
#   inflating: /content/data/Images/Images/digit_7/5746.png
#   inflating: /content/data/Images/Images/digit_7/5747.png
#   inflating: /content/data/Images/Images/digit_7/5748.png
#   inflating: /content/data/Images/Images/digit_7/5749.png
#   inflating: /content/data/Images/Images/digit_7/5750.png
#   inflating: /content/data/Images/Images/digit_7/5751.png
#   inflating: /content/data/Images/Images/digit_7/5752.png
#   inflating: /content/data/Images/Images/digit_7/5753.png
#   inflating: /content/data/Images/Images/digit_7/5754.png
#   inflating: /content/data/Images/Images/digit_7/5755.png
#   inflating: /content/data/Images/Images/digit_7/5756.png
#   inflating: /content/data/Images/Images/digit_7/5757.png
#   inflating: /content/data/Images/Images/digit_7/5758.png
#   inflating: /content/data/Images/Images/digit_7/5759.png
#   inflating: /content/data/Images/Images/digit_7/5760.png
#   inflating: /content/data/Images/Images/digit_7/5761.png
#   inflating: /content/data/Images/Images/digit_7/5762.png
#   inflating: /content/data/Images/Images/digit_7/5763.png
#   inflating: /content/data/Images/Images/digit_7/5764.png
#   inflating: /content/data/Images/Images/digit_7/5765.png
#   inflating: /content/data/Images/Images/digit_7/5766.png
#   inflating: /content/data/Images/Images/digit_7/5767.png
#   inflating: /content/data/Images/Images/digit_7/5768.png
#   inflating: /content/data/Images/Images/digit_7/5769.png
#   inflating: /content/data/Images/Images/digit_7/5770.png
#   inflating: /content/data/Images/Images/digit_7/5771.png
#   inflating: /content/data/Images/Images/digit_7/5772.png
#   inflating: /content/data/Images/Images/digit_7/5773.png
#   inflating: /content/data/Images/Images/digit_7/5774.png
#   inflating: /content/data/Images/Images/digit_7/5775.png
#   inflating: /content/data/Images/Images/digit_7/5776.png
#   inflating: /content/data/Images/Images/digit_7/5777.png
#   inflating: /content/data/Images/Images/digit_7/5778.png
#   inflating: /content/data/Images/Images/digit_7/5779.png
#   inflating: /content/data/Images/Images/digit_7/5780.png
#   inflating: /content/data/Images/Images/digit_7/5781.png
#   inflating: /content/data/Images/Images/digit_7/5782.png
#   inflating: /content/data/Images/Images/digit_7/5783.png
#   inflating: /content/data/Images/Images/digit_7/5784.png
#   inflating: /content/data/Images/Images/digit_7/5785.png
#   inflating: /content/data/Images/Images/digit_7/5786.png
#   inflating: /content/data/Images/Images/digit_7/5787.png
#   inflating: /content/data/Images/Images/digit_7/5788.png
#   inflating: /content/data/Images/Images/digit_7/5789.png
#   inflating: /content/data/Images/Images/digit_7/5790.png
#   inflating: /content/data/Images/Images/digit_7/5791.png
#   inflating: /content/data/Images/Images/digit_7/5792.png
#   inflating: /content/data/Images/Images/digit_7/5793.png
#   inflating: /content/data/Images/Images/digit_7/5794.png
#   inflating: /content/data/Images/Images/digit_7/5795.png
#   inflating: /content/data/Images/Images/digit_7/5796.png
#   inflating: /content/data/Images/Images/digit_7/5797.png
#   inflating: /content/data/Images/Images/digit_7/5798.png
#   inflating: /content/data/Images/Images/digit_7/5799.png
#   inflating: /content/data/Images/Images/digit_7/5800.png
#   inflating: /content/data/Images/Images/digit_7/5801.png
#   inflating: /content/data/Images/Images/digit_7/5802.png
#   inflating: /content/data/Images/Images/digit_7/5803.png
#   inflating: /content/data/Images/Images/digit_7/5804.png
#   inflating: /content/data/Images/Images/digit_7/5805.png
#   inflating: /content/data/Images/Images/digit_7/5806.png
#   inflating: /content/data/Images/Images/digit_7/5807.png
#   inflating: /content/data/Images/Images/digit_7/5808.png
#   inflating: /content/data/Images/Images/digit_7/5809.png
#   inflating: /content/data/Images/Images/digit_7/5810.png
#   inflating: /content/data/Images/Images/digit_7/5811.png
#   inflating: /content/data/Images/Images/digit_7/5812.png
#   inflating: /content/data/Images/Images/digit_7/5813.png
#   inflating: /content/data/Images/Images/digit_7/5814.png
#   inflating: /content/data/Images/Images/digit_7/5815.png
#   inflating: /content/data/Images/Images/digit_7/5816.png
#   inflating: /content/data/Images/Images/digit_7/5817.png
#   inflating: /content/data/Images/Images/digit_7/5818.png
#   inflating: /content/data/Images/Images/digit_7/5819.png
#   inflating: /content/data/Images/Images/digit_7/67953.png
#   inflating: /content/data/Images/Images/digit_7/67954.png
#   inflating: /content/data/Images/Images/digit_7/67955.png
#   inflating: /content/data/Images/Images/digit_7/67956.png
#   inflating: /content/data/Images/Images/digit_7/67957.png
#   inflating: /content/data/Images/Images/digit_7/67958.png
#   inflating: /content/data/Images/Images/digit_7/67959.png
#   inflating: /content/data/Images/Images/digit_7/67960.png
#   inflating: /content/data/Images/Images/digit_7/67961.png
#   inflating: /content/data/Images/Images/digit_7/67962.png
#   inflating: /content/data/Images/Images/digit_7/67963.png
#   inflating: /content/data/Images/Images/digit_7/67964.png
#   inflating: /content/data/Images/Images/digit_7/67965.png
#   inflating: /content/data/Images/Images/digit_7/67966.png
#   inflating: /content/data/Images/Images/digit_7/67967.png
#   inflating: /content/data/Images/Images/digit_7/67968.png
#   inflating: /content/data/Images/Images/digit_7/67969.png
#   inflating: /content/data/Images/Images/digit_7/67970.png
#   inflating: /content/data/Images/Images/digit_7/67971.png
#   inflating: /content/data/Images/Images/digit_7/67972.png
#   inflating: /content/data/Images/Images/digit_7/67973.png
#   inflating: /content/data/Images/Images/digit_7/67974.png
#   inflating: /content/data/Images/Images/digit_7/67975.png
#   inflating: /content/data/Images/Images/digit_7/67976.png
#   inflating: /content/data/Images/Images/digit_7/67977.png
#   inflating: /content/data/Images/Images/digit_7/67978.png
#   inflating: /content/data/Images/Images/digit_7/67979.png
#   inflating: /content/data/Images/Images/digit_7/67980.png
#   inflating: /content/data/Images/Images/digit_7/67981.png
#   inflating: /content/data/Images/Images/digit_7/67982.png
#   inflating: /content/data/Images/Images/digit_7/67983.png
#   inflating: /content/data/Images/Images/digit_7/67984.png
#   inflating: /content/data/Images/Images/digit_7/67985.png
#   inflating: /content/data/Images/Images/digit_7/67986.png
#   inflating: /content/data/Images/Images/digit_7/67987.png
#   inflating: /content/data/Images/Images/digit_7/67988.png
#   inflating: /content/data/Images/Images/digit_7/67989.png
#   inflating: /content/data/Images/Images/digit_7/67990.png
#   inflating: /content/data/Images/Images/digit_7/67991.png
#   inflating: /content/data/Images/Images/digit_7/67992.png
#   inflating: /content/data/Images/Images/digit_7/67993.png
#   inflating: /content/data/Images/Images/digit_7/67994.png
#   inflating: /content/data/Images/Images/digit_7/67995.png
#   inflating: /content/data/Images/Images/digit_7/67996.png
#   inflating: /content/data/Images/Images/digit_7/67997.png
#   inflating: /content/data/Images/Images/digit_7/67998.png
#   inflating: /content/data/Images/Images/digit_7/67999.png
#   inflating: /content/data/Images/Images/digit_7/68000.png
#   inflating: /content/data/Images/Images/digit_7/68001.png
#   inflating: /content/data/Images/Images/digit_7/68002.png
#   inflating: /content/data/Images/Images/digit_7/68003.png
#   inflating: /content/data/Images/Images/digit_7/68004.png
#   inflating: /content/data/Images/Images/digit_7/68005.png
#   inflating: /content/data/Images/Images/digit_7/68006.png
#   inflating: /content/data/Images/Images/digit_7/68007.png
#   inflating: /content/data/Images/Images/digit_7/68008.png
#   inflating: /content/data/Images/Images/digit_7/68009.png
#   inflating: /content/data/Images/Images/digit_7/68010.png
#   inflating: /content/data/Images/Images/digit_7/68011.png
#   inflating: /content/data/Images/Images/digit_7/68012.png
#   inflating: /content/data/Images/Images/digit_7/68013.png
#   inflating: /content/data/Images/Images/digit_7/68014.png
#   inflating: /content/data/Images/Images/digit_7/68015.png
#   inflating: /content/data/Images/Images/digit_7/68016.png
#   inflating: /content/data/Images/Images/digit_7/68017.png
#   inflating: /content/data/Images/Images/digit_7/68018.png
#   inflating: /content/data/Images/Images/digit_7/68019.png
#   inflating: /content/data/Images/Images/digit_7/68020.png
#   inflating: /content/data/Images/Images/digit_7/68021.png
#   inflating: /content/data/Images/Images/digit_7/68022.png
#   inflating: /content/data/Images/Images/digit_7/68023.png
#   inflating: /content/data/Images/Images/digit_7/68024.png
#   inflating: /content/data/Images/Images/digit_7/68025.png
#   inflating: /content/data/Images/Images/digit_7/68026.png
#   inflating: /content/data/Images/Images/digit_7/68027.png
#   inflating: /content/data/Images/Images/digit_7/68028.png
#   inflating: /content/data/Images/Images/digit_7/68029.png
#   inflating: /content/data/Images/Images/digit_7/68030.png
#   inflating: /content/data/Images/Images/digit_7/68031.png
#   inflating: /content/data/Images/Images/digit_7/68032.png
#   inflating: /content/data/Images/Images/digit_7/68033.png
#   inflating: /content/data/Images/Images/digit_7/68034.png
#   inflating: /content/data/Images/Images/digit_7/68035.png
#   inflating: /content/data/Images/Images/digit_7/68036.png
#   inflating: /content/data/Images/Images/digit_7/68037.png
#   inflating: /content/data/Images/Images/digit_7/68038.png
#   inflating: /content/data/Images/Images/digit_7/68039.png
#   inflating: /content/data/Images/Images/digit_7/68040.png
#   inflating: /content/data/Images/Images/digit_7/68041.png
#   inflating: /content/data/Images/Images/digit_7/68042.png
#   inflating: /content/data/Images/Images/digit_7/68043.png
#   inflating: /content/data/Images/Images/digit_7/68044.png
#   inflating: /content/data/Images/Images/digit_7/68045.png
#   inflating: /content/data/Images/Images/digit_7/68046.png
#   inflating: /content/data/Images/Images/digit_7/68047.png
#   inflating: /content/data/Images/Images/digit_7/68048.png
#   inflating: /content/data/Images/Images/digit_7/68049.png
#   inflating: /content/data/Images/Images/digit_7/68050.png
#   inflating: /content/data/Images/Images/digit_7/68051.png
#   inflating: /content/data/Images/Images/digit_7/68052.png
#   inflating: /content/data/Images/Images/digit_7/68053.png
#   inflating: /content/data/Images/Images/digit_7/68054.png
#   inflating: /content/data/Images/Images/digit_7/68055.png
#   inflating: /content/data/Images/Images/digit_7/68056.png
#   inflating: /content/data/Images/Images/digit_7/68057.png
#   inflating: /content/data/Images/Images/digit_7/68058.png
#   inflating: /content/data/Images/Images/digit_7/68059.png
#   inflating: /content/data/Images/Images/digit_7/68060.png
#   inflating: /content/data/Images/Images/digit_7/68061.png
#   inflating: /content/data/Images/Images/digit_7/68062.png
#   inflating: /content/data/Images/Images/digit_7/68063.png
#   inflating: /content/data/Images/Images/digit_7/68064.png
#   inflating: /content/data/Images/Images/digit_7/68065.png
#   inflating: /content/data/Images/Images/digit_7/68066.png
#   inflating: /content/data/Images/Images/digit_7/68067.png
#   inflating: /content/data/Images/Images/digit_7/68068.png
#   inflating: /content/data/Images/Images/digit_7/68069.png
#   inflating: /content/data/Images/Images/digit_7/68070.png
#   inflating: /content/data/Images/Images/digit_7/68071.png
#   inflating: /content/data/Images/Images/digit_7/68072.png
#   inflating: /content/data/Images/Images/digit_7/68073.png
#   inflating: /content/data/Images/Images/digit_7/68074.png
#   inflating: /content/data/Images/Images/digit_7/68075.png
#   inflating: /content/data/Images/Images/digit_7/68076.png
#   inflating: /content/data/Images/Images/digit_7/68077.png
#   inflating: /content/data/Images/Images/digit_7/68078.png
#   inflating: /content/data/Images/Images/digit_7/68079.png
#   inflating: /content/data/Images/Images/digit_7/68080.png
#   inflating: /content/data/Images/Images/digit_7/68081.png
#   inflating: /content/data/Images/Images/digit_7/68082.png
#   inflating: /content/data/Images/Images/digit_7/68083.png
#   inflating: /content/data/Images/Images/digit_7/68084.png
#   inflating: /content/data/Images/Images/digit_7/68085.png
#   inflating: /content/data/Images/Images/digit_7/68086.png
#   inflating: /content/data/Images/Images/digit_7/68087.png
#   inflating: /content/data/Images/Images/digit_7/68088.png
#   inflating: /content/data/Images/Images/digit_7/68089.png
#   inflating: /content/data/Images/Images/digit_7/68090.png
#   inflating: /content/data/Images/Images/digit_7/68091.png
#   inflating: /content/data/Images/Images/digit_7/68092.png
#   inflating: /content/data/Images/Images/digit_7/68093.png
#   inflating: /content/data/Images/Images/digit_7/68094.png
#   inflating: /content/data/Images/Images/digit_7/68095.png
#   inflating: /content/data/Images/Images/digit_7/68096.png
#   inflating: /content/data/Images/Images/digit_7/68097.png
#   inflating: /content/data/Images/Images/digit_7/68098.png
#   inflating: /content/data/Images/Images/digit_7/68099.png
#   inflating: /content/data/Images/Images/digit_7/68100.png
#   inflating: /content/data/Images/Images/digit_7/68101.png
#   inflating: /content/data/Images/Images/digit_7/68102.png
#   inflating: /content/data/Images/Images/digit_7/68103.png
#   inflating: /content/data/Images/Images/digit_7/68104.png
#   inflating: /content/data/Images/Images/digit_7/68105.png
#   inflating: /content/data/Images/Images/digit_7/68106.png
#   inflating: /content/data/Images/Images/digit_7/68107.png
#   inflating: /content/data/Images/Images/digit_7/68108.png
#   inflating: /content/data/Images/Images/digit_7/68109.png
#   inflating: /content/data/Images/Images/digit_7/68110.png
#   inflating: /content/data/Images/Images/digit_7/68111.png
#   inflating: /content/data/Images/Images/digit_7/68112.png
#   inflating: /content/data/Images/Images/digit_7/68113.png
#   inflating: /content/data/Images/Images/digit_7/68114.png
#   inflating: /content/data/Images/Images/digit_7/68115.png
#   inflating: /content/data/Images/Images/digit_7/68116.png
#   inflating: /content/data/Images/Images/digit_7/68117.png
#   inflating: /content/data/Images/Images/digit_7/68118.png
#   inflating: /content/data/Images/Images/digit_7/68119.png
#   inflating: /content/data/Images/Images/digit_7/68120.png
#   inflating: /content/data/Images/Images/digit_7/68121.png
#   inflating: /content/data/Images/Images/digit_7/68122.png
#   inflating: /content/data/Images/Images/digit_7/68123.png
#   inflating: /content/data/Images/Images/digit_7/68124.png
#   inflating: /content/data/Images/Images/digit_7/68125.png
#   inflating: /content/data/Images/Images/digit_7/68126.png
#   inflating: /content/data/Images/Images/digit_7/68127.png
#   inflating: /content/data/Images/Images/digit_7/68128.png
#   inflating: /content/data/Images/Images/digit_7/68129.png
#   inflating: /content/data/Images/Images/digit_7/68130.png
#   inflating: /content/data/Images/Images/digit_7/68131.png
#   inflating: /content/data/Images/Images/digit_7/68132.png
#   inflating: /content/data/Images/Images/digit_7/68133.png
#   inflating: /content/data/Images/Images/digit_7/68134.png
#   inflating: /content/data/Images/Images/digit_7/68135.png
#   inflating: /content/data/Images/Images/digit_7/68136.png
#   inflating: /content/data/Images/Images/digit_7/68137.png
#   inflating: /content/data/Images/Images/digit_7/68138.png
#   inflating: /content/data/Images/Images/digit_7/68139.png
#   inflating: /content/data/Images/Images/digit_7/68140.png
#   inflating: /content/data/Images/Images/digit_7/68141.png
#   inflating: /content/data/Images/Images/digit_7/68142.png
#   inflating: /content/data/Images/Images/digit_7/68143.png
#   inflating: /content/data/Images/Images/digit_7/68144.png
#   inflating: /content/data/Images/Images/digit_7/68145.png
#   inflating: /content/data/Images/Images/digit_7/68146.png
#   inflating: /content/data/Images/Images/digit_7/68147.png
#   inflating: /content/data/Images/Images/digit_7/68148.png
#   inflating: /content/data/Images/Images/digit_7/68149.png
#   inflating: /content/data/Images/Images/digit_7/68150.png
#   inflating: /content/data/Images/Images/digit_7/68151.png
#   inflating: /content/data/Images/Images/digit_7/68152.png
#   inflating: /content/data/Images/Images/digit_7/68153.png
#   inflating: /content/data/Images/Images/digit_7/68154.png
#   inflating: /content/data/Images/Images/digit_7/68155.png
#   inflating: /content/data/Images/Images/digit_7/68156.png
#   inflating: /content/data/Images/Images/digit_7/68157.png
#   inflating: /content/data/Images/Images/digit_7/68158.png
#   inflating: /content/data/Images/Images/digit_7/68159.png
#   inflating: /content/data/Images/Images/digit_7/68160.png
#   inflating: /content/data/Images/Images/digit_7/68161.png
#   inflating: /content/data/Images/Images/digit_7/68162.png
#   inflating: /content/data/Images/Images/digit_7/68163.png
#   inflating: /content/data/Images/Images/digit_7/68164.png
#   inflating: /content/data/Images/Images/digit_7/68165.png
#   inflating: /content/data/Images/Images/digit_7/68166.png
#   inflating: /content/data/Images/Images/digit_7/68167.png
#   inflating: /content/data/Images/Images/digit_7/68168.png
#   inflating: /content/data/Images/Images/digit_7/68169.png
#   inflating: /content/data/Images/Images/digit_7/68170.png
#   inflating: /content/data/Images/Images/digit_7/68171.png
#   inflating: /content/data/Images/Images/digit_7/68172.png
#   inflating: /content/data/Images/Images/digit_7/68173.png
#   inflating: /content/data/Images/Images/digit_7/68174.png
#   inflating: /content/data/Images/Images/digit_7/68175.png
#   inflating: /content/data/Images/Images/digit_7/68176.png
#   inflating: /content/data/Images/Images/digit_7/68177.png
#   inflating: /content/data/Images/Images/digit_7/68178.png
#   inflating: /content/data/Images/Images/digit_7/68179.png
#   inflating: /content/data/Images/Images/digit_7/68180.png
#   inflating: /content/data/Images/Images/digit_7/68181.png
#   inflating: /content/data/Images/Images/digit_7/68182.png
#   inflating: /content/data/Images/Images/digit_7/68183.png
#   inflating: /content/data/Images/Images/digit_7/68184.png
#   inflating: /content/data/Images/Images/digit_7/68185.png
#   inflating: /content/data/Images/Images/digit_7/68186.png
#   inflating: /content/data/Images/Images/digit_7/68187.png
#   inflating: /content/data/Images/Images/digit_7/68188.png
#   inflating: /content/data/Images/Images/digit_7/68189.png
#   inflating: /content/data/Images/Images/digit_7/68190.png
#   inflating: /content/data/Images/Images/digit_7/68191.png
#   inflating: /content/data/Images/Images/digit_7/68192.png
#   inflating: /content/data/Images/Images/digit_7/68193.png
#   inflating: /content/data/Images/Images/digit_7/68194.png
#   inflating: /content/data/Images/Images/digit_7/68195.png
#   inflating: /content/data/Images/Images/digit_7/68196.png
#   inflating: /content/data/Images/Images/digit_7/68197.png
#   inflating: /content/data/Images/Images/digit_7/68198.png
#   inflating: /content/data/Images/Images/digit_7/68199.png
#   inflating: /content/data/Images/Images/digit_7/68200.png
#   inflating: /content/data/Images/Images/digit_7/68201.png
#   inflating: /content/data/Images/Images/digit_7/68202.png
#   inflating: /content/data/Images/Images/digit_7/68203.png
#   inflating: /content/data/Images/Images/digit_7/68204.png
#   inflating: /content/data/Images/Images/digit_7/68205.png
#   inflating: /content/data/Images/Images/digit_7/68206.png
#   inflating: /content/data/Images/Images/digit_7/68207.png
#   inflating: /content/data/Images/Images/digit_7/68208.png
#   inflating: /content/data/Images/Images/digit_7/68209.png
#   inflating: /content/data/Images/Images/digit_7/68210.png
#   inflating: /content/data/Images/Images/digit_7/68211.png
#   inflating: /content/data/Images/Images/digit_7/68212.png
#   inflating: /content/data/Images/Images/digit_7/68213.png
#   inflating: /content/data/Images/Images/digit_7/69140.png
#   inflating: /content/data/Images/Images/digit_7/69141.png
#   inflating: /content/data/Images/Images/digit_7/69142.png
#   inflating: /content/data/Images/Images/digit_7/69143.png
#   inflating: /content/data/Images/Images/digit_7/69144.png
#   inflating: /content/data/Images/Images/digit_7/69145.png
#   inflating: /content/data/Images/Images/digit_7/69146.png
#   inflating: /content/data/Images/Images/digit_7/69147.png
#   inflating: /content/data/Images/Images/digit_7/69148.png
#   inflating: /content/data/Images/Images/digit_7/71321.png
#   inflating: /content/data/Images/Images/digit_7/71322.png
#   inflating: /content/data/Images/Images/digit_7/71323.png
#   inflating: /content/data/Images/Images/digit_7/71324.png
#   inflating: /content/data/Images/Images/digit_7/71325.png
#   inflating: /content/data/Images/Images/digit_7/71326.png
#   inflating: /content/data/Images/Images/digit_7/71327.png
#   inflating: /content/data/Images/Images/digit_7/71328.png
#   inflating: /content/data/Images/Images/digit_7/71329.png
#   inflating: /content/data/Images/Images/digit_7/71330.png
#   inflating: /content/data/Images/Images/digit_7/71331.png
#   inflating: /content/data/Images/Images/digit_7/71332.png
#   inflating: /content/data/Images/Images/digit_7/71333.png
#   inflating: /content/data/Images/Images/digit_7/71334.png
#   inflating: /content/data/Images/Images/digit_7/71335.png
#   inflating: /content/data/Images/Images/digit_7/71336.png
#   inflating: /content/data/Images/Images/digit_7/71337.png
#   inflating: /content/data/Images/Images/digit_7/71338.png
#   inflating: /content/data/Images/Images/digit_7/71339.png
#   inflating: /content/data/Images/Images/digit_7/7171.png
#   inflating: /content/data/Images/Images/digit_7/7172.png
#   inflating: /content/data/Images/Images/digit_7/7173.png
#   inflating: /content/data/Images/Images/digit_7/7174.png
#   inflating: /content/data/Images/Images/digit_7/7175.png
#   inflating: /content/data/Images/Images/digit_7/7176.png
#   inflating: /content/data/Images/Images/digit_7/7177.png
#   inflating: /content/data/Images/Images/digit_7/7178.png
#   inflating: /content/data/Images/Images/digit_7/7179.png
#   inflating: /content/data/Images/Images/digit_7/7180.png
#   inflating: /content/data/Images/Images/digit_7/7181.png
#   inflating: /content/data/Images/Images/digit_7/7182.png
#   inflating: /content/data/Images/Images/digit_7/7183.png
#   inflating: /content/data/Images/Images/digit_7/7184.png
#   inflating: /content/data/Images/Images/digit_7/7185.png
#   inflating: /content/data/Images/Images/digit_7/7186.png
#   inflating: /content/data/Images/Images/digit_7/7187.png
#   inflating: /content/data/Images/Images/digit_7/7188.png
#   inflating: /content/data/Images/Images/digit_7/7189.png
#   inflating: /content/data/Images/Images/digit_7/7190.png
#   inflating: /content/data/Images/Images/digit_7/7191.png
#   inflating: /content/data/Images/Images/digit_7/7192.png
#   inflating: /content/data/Images/Images/digit_7/7193.png
#   inflating: /content/data/Images/Images/digit_7/7194.png
#   inflating: /content/data/Images/Images/digit_7/7195.png
#   inflating: /content/data/Images/Images/digit_7/7196.png
#   inflating: /content/data/Images/Images/digit_7/7197.png
#   inflating: /content/data/Images/Images/digit_7/7198.png
#   inflating: /content/data/Images/Images/digit_7/7199.png
#   inflating: /content/data/Images/Images/digit_7/7200.png
#   inflating: /content/data/Images/Images/digit_7/7201.png
#   inflating: /content/data/Images/Images/digit_7/7202.png
#   inflating: /content/data/Images/Images/digit_7/7203.png
#   inflating: /content/data/Images/Images/digit_7/7204.png
#   inflating: /content/data/Images/Images/digit_7/7205.png
#   inflating: /content/data/Images/Images/digit_7/7206.png
#   inflating: /content/data/Images/Images/digit_7/7207.png
#   inflating: /content/data/Images/Images/digit_7/7208.png
#   inflating: /content/data/Images/Images/digit_7/7209.png
#   inflating: /content/data/Images/Images/digit_7/7210.png
#   inflating: /content/data/Images/Images/digit_7/7211.png
#   inflating: /content/data/Images/Images/digit_7/7212.png
#   inflating: /content/data/Images/Images/digit_7/7213.png
#   inflating: /content/data/Images/Images/digit_7/7214.png
#   inflating: /content/data/Images/Images/digit_7/7215.png
#   inflating: /content/data/Images/Images/digit_7/7216.png
#   inflating: /content/data/Images/Images/digit_7/7217.png
#   inflating: /content/data/Images/Images/digit_7/7218.png
#   inflating: /content/data/Images/Images/digit_7/7219.png
#   inflating: /content/data/Images/Images/digit_7/7220.png
#   inflating: /content/data/Images/Images/digit_7/78195.png
#   inflating: /content/data/Images/Images/digit_7/78196.png
#   inflating: /content/data/Images/Images/digit_7/78197.png
#   inflating: /content/data/Images/Images/digit_7/78198.png
#   inflating: /content/data/Images/Images/digit_7/78199.png
#   inflating: /content/data/Images/Images/digit_7/78200.png
#   inflating: /content/data/Images/Images/digit_7/78201.png
#   inflating: /content/data/Images/Images/digit_7/78202.png
#   inflating: /content/data/Images/Images/digit_7/78203.png
#   inflating: /content/data/Images/Images/digit_7/78204.png
#   inflating: /content/data/Images/Images/digit_7/78205.png
#   inflating: /content/data/Images/Images/digit_7/78206.png
#   inflating: /content/data/Images/Images/digit_7/78207.png
#   inflating: /content/data/Images/Images/digit_7/78208.png
#   inflating: /content/data/Images/Images/digit_7/78209.png
#   inflating: /content/data/Images/Images/digit_7/78210.png
#   inflating: /content/data/Images/Images/digit_7/78211.png
#   inflating: /content/data/Images/Images/digit_7/78212.png
#   inflating: /content/data/Images/Images/digit_7/78213.png
#   inflating: /content/data/Images/Images/digit_7/78214.png
#   inflating: /content/data/Images/Images/digit_7/78215.png
#   inflating: /content/data/Images/Images/digit_7/78216.png
#   inflating: /content/data/Images/Images/digit_7/78217.png
#   inflating: /content/data/Images/Images/digit_7/78218.png
#   inflating: /content/data/Images/Images/digit_7/78219.png
#   inflating: /content/data/Images/Images/digit_7/78220.png
#   inflating: /content/data/Images/Images/digit_7/78221.png
#   inflating: /content/data/Images/Images/digit_7/78222.png
#   inflating: /content/data/Images/Images/digit_7/78223.png
#   inflating: /content/data/Images/Images/digit_7/78224.png
#   inflating: /content/data/Images/Images/digit_7/78225.png
#   inflating: /content/data/Images/Images/digit_7/78226.png
#   inflating: /content/data/Images/Images/digit_7/78227.png
#   inflating: /content/data/Images/Images/digit_7/78228.png
#   inflating: /content/data/Images/Images/digit_7/78229.png
#   inflating: /content/data/Images/Images/digit_7/78230.png
#   inflating: /content/data/Images/Images/digit_7/78231.png
#   inflating: /content/data/Images/Images/digit_7/78232.png
#   inflating: /content/data/Images/Images/digit_7/78233.png
#   inflating: /content/data/Images/Images/digit_7/78234.png
#   inflating: /content/data/Images/Images/digit_7/78235.png
#   inflating: /content/data/Images/Images/digit_7/78236.png
#   inflating: /content/data/Images/Images/digit_7/78237.png
#   inflating: /content/data/Images/Images/digit_7/78238.png
#   inflating: /content/data/Images/Images/digit_7/78239.png
#   inflating: /content/data/Images/Images/digit_7/78240.png
#   inflating: /content/data/Images/Images/digit_7/78241.png
#   inflating: /content/data/Images/Images/digit_7/78242.png
#   inflating: /content/data/Images/Images/digit_7/78243.png
#   inflating: /content/data/Images/Images/digit_7/78244.png
#   inflating: /content/data/Images/Images/digit_7/78245.png
#   inflating: /content/data/Images/Images/digit_7/78246.png
#   inflating: /content/data/Images/Images/digit_7/78247.png
#   inflating: /content/data/Images/Images/digit_7/78248.png
#   inflating: /content/data/Images/Images/digit_7/78249.png
#   inflating: /content/data/Images/Images/digit_7/78250.png
#   inflating: /content/data/Images/Images/digit_7/78251.png
#   inflating: /content/data/Images/Images/digit_7/78252.png
#   inflating: /content/data/Images/Images/digit_7/78253.png
#   inflating: /content/data/Images/Images/digit_7/78254.png
#   inflating: /content/data/Images/Images/digit_7/78255.png
#   inflating: /content/data/Images/Images/digit_7/78256.png
#   inflating: /content/data/Images/Images/digit_7/78257.png
#   inflating: /content/data/Images/Images/digit_7/78258.png
#   inflating: /content/data/Images/Images/digit_7/78259.png
#   inflating: /content/data/Images/Images/digit_7/78260.png
#   inflating: /content/data/Images/Images/digit_7/78261.png
#   inflating: /content/data/Images/Images/digit_7/78262.png
#   inflating: /content/data/Images/Images/digit_7/78263.png
#   inflating: /content/data/Images/Images/digit_7/78264.png
#   inflating: /content/data/Images/Images/digit_7/78265.png
#   inflating: /content/data/Images/Images/digit_7/78266.png
#   inflating: /content/data/Images/Images/digit_7/78267.png
#   inflating: /content/data/Images/Images/digit_7/78268.png
#   inflating: /content/data/Images/Images/digit_7/78269.png
#   inflating: /content/data/Images/Images/digit_7/78270.png
#   inflating: /content/data/Images/Images/digit_7/78271.png
#   inflating: /content/data/Images/Images/digit_7/78272.png
#   inflating: /content/data/Images/Images/digit_7/78273.png
#   inflating: /content/data/Images/Images/digit_7/78274.png
#   inflating: /content/data/Images/Images/digit_7/78275.png
#   inflating: /content/data/Images/Images/digit_7/78276.png
#   inflating: /content/data/Images/Images/digit_7/78277.png
#   inflating: /content/data/Images/Images/digit_7/78278.png
#   inflating: /content/data/Images/Images/digit_7/78279.png
#   inflating: /content/data/Images/Images/digit_7/78280.png
#   inflating: /content/data/Images/Images/digit_7/78281.png
#   inflating: /content/data/Images/Images/digit_7/78282.png
#   inflating: /content/data/Images/Images/digit_7/78283.png
#   inflating: /content/data/Images/Images/digit_7/78284.png
#   inflating: /content/data/Images/Images/digit_7/78285.png
#   inflating: /content/data/Images/Images/digit_7/78286.png
#   inflating: /content/data/Images/Images/digit_7/78287.png
#   inflating: /content/data/Images/Images/digit_7/78288.png
#   inflating: /content/data/Images/Images/digit_7/78289.png
#   inflating: /content/data/Images/Images/digit_7/78290.png
#   inflating: /content/data/Images/Images/digit_7/78291.png
#   inflating: /content/data/Images/Images/digit_7/78292.png
#   inflating: /content/data/Images/Images/digit_7/78293.png
#   inflating: /content/data/Images/Images/digit_7/78294.png
#   inflating: /content/data/Images/Images/digit_7/78295.png
#   inflating: /content/data/Images/Images/digit_7/78296.png
#   inflating: /content/data/Images/Images/digit_7/78297.png
#   inflating: /content/data/Images/Images/digit_7/78298.png
#   inflating: /content/data/Images/Images/digit_7/78299.png
#   inflating: /content/data/Images/Images/digit_7/78300.png
#   inflating: /content/data/Images/Images/digit_7/78301.png
#   inflating: /content/data/Images/Images/digit_7/78302.png
#   inflating: /content/data/Images/Images/digit_7/78303.png
#   inflating: /content/data/Images/Images/digit_7/78304.png
#   inflating: /content/data/Images/Images/digit_7/78305.png
#   inflating: /content/data/Images/Images/digit_7/78306.png
#   inflating: /content/data/Images/Images/digit_7/78307.png
#   inflating: /content/data/Images/Images/digit_7/78308.png
#   inflating: /content/data/Images/Images/digit_7/78309.png
#   inflating: /content/data/Images/Images/digit_7/78310.png
#   inflating: /content/data/Images/Images/digit_7/78311.png
#   inflating: /content/data/Images/Images/digit_7/78312.png
#   inflating: /content/data/Images/Images/digit_7/78313.png
#   inflating: /content/data/Images/Images/digit_7/78314.png
#   inflating: /content/data/Images/Images/digit_7/78315.png
#   inflating: /content/data/Images/Images/digit_7/78316.png
#   inflating: /content/data/Images/Images/digit_7/78317.png
#   inflating: /content/data/Images/Images/digit_7/78318.png
#   inflating: /content/data/Images/Images/digit_7/78319.png
#   inflating: /content/data/Images/Images/digit_7/78320.png
#   inflating: /content/data/Images/Images/digit_7/78321.png
#   inflating: /content/data/Images/Images/digit_7/78322.png
#   inflating: /content/data/Images/Images/digit_7/78323.png
#   inflating: /content/data/Images/Images/digit_7/78324.png
#   inflating: /content/data/Images/Images/digit_7/78325.png
#   inflating: /content/data/Images/Images/digit_7/78326.png
#   inflating: /content/data/Images/Images/digit_7/78327.png
#   inflating: /content/data/Images/Images/digit_7/78328.png
#   inflating: /content/data/Images/Images/digit_7/78329.png
#   inflating: /content/data/Images/Images/digit_7/78330.png
#   inflating: /content/data/Images/Images/digit_7/78331.png
#   inflating: /content/data/Images/Images/digit_7/78332.png
#   inflating: /content/data/Images/Images/digit_7/78333.png
#   inflating: /content/data/Images/Images/digit_7/78334.png
#   inflating: /content/data/Images/Images/digit_7/78335.png
#   inflating: /content/data/Images/Images/digit_7/78336.png
#   inflating: /content/data/Images/Images/digit_7/78337.png
#   inflating: /content/data/Images/Images/digit_7/78338.png
#   inflating: /content/data/Images/Images/digit_7/78339.png
#   inflating: /content/data/Images/Images/digit_7/78340.png
#   inflating: /content/data/Images/Images/digit_7/78341.png
#   inflating: /content/data/Images/Images/digit_7/78342.png
#   inflating: /content/data/Images/Images/digit_7/78343.png
#   inflating: /content/data/Images/Images/digit_7/78344.png
#   inflating: /content/data/Images/Images/digit_7/78345.png
#   inflating: /content/data/Images/Images/digit_7/78346.png
#   inflating: /content/data/Images/Images/digit_7/78347.png
#   inflating: /content/data/Images/Images/digit_7/78348.png
#   inflating: /content/data/Images/Images/digit_7/78349.png
#   inflating: /content/data/Images/Images/digit_7/78350.png
#   inflating: /content/data/Images/Images/digit_7/78351.png
#   inflating: /content/data/Images/Images/digit_7/78352.png
#   inflating: /content/data/Images/Images/digit_7/78353.png
#   inflating: /content/data/Images/Images/digit_7/78354.png
#   inflating: /content/data/Images/Images/digit_7/78355.png
#   inflating: /content/data/Images/Images/digit_7/78356.png
#   inflating: /content/data/Images/Images/digit_7/78357.png
#   inflating: /content/data/Images/Images/digit_7/78358.png
#   inflating: /content/data/Images/Images/digit_7/78359.png
#   inflating: /content/data/Images/Images/digit_7/78360.png
#   inflating: /content/data/Images/Images/digit_7/78361.png
#   inflating: /content/data/Images/Images/digit_7/78362.png
#   inflating: /content/data/Images/Images/digit_7/78363.png
#   inflating: /content/data/Images/Images/digit_7/78364.png
#   inflating: /content/data/Images/Images/digit_7/78365.png
#   inflating: /content/data/Images/Images/digit_7/78366.png
#   inflating: /content/data/Images/Images/digit_7/78367.png
#   inflating: /content/data/Images/Images/digit_7/78368.png
#   inflating: /content/data/Images/Images/digit_7/78369.png
#   inflating: /content/data/Images/Images/digit_7/78370.png
#   inflating: /content/data/Images/Images/digit_7/78371.png
#   inflating: /content/data/Images/Images/digit_7/78372.png
#   inflating: /content/data/Images/Images/digit_7/78373.png
#   inflating: /content/data/Images/Images/digit_7/78374.png
#   inflating: /content/data/Images/Images/digit_7/78375.png
#   inflating: /content/data/Images/Images/digit_7/78376.png
#   inflating: /content/data/Images/Images/digit_7/78377.png
#   inflating: /content/data/Images/Images/digit_7/78378.png
#   inflating: /content/data/Images/Images/digit_7/78379.png
#   inflating: /content/data/Images/Images/digit_7/78380.png
#   inflating: /content/data/Images/Images/digit_7/78381.png
#   inflating: /content/data/Images/Images/digit_7/78382.png
#   inflating: /content/data/Images/Images/digit_7/78383.png
#   inflating: /content/data/Images/Images/digit_7/78384.png
#   inflating: /content/data/Images/Images/digit_7/78385.png
#   inflating: /content/data/Images/Images/digit_7/78386.png
#   inflating: /content/data/Images/Images/digit_7/78387.png
#   inflating: /content/data/Images/Images/digit_7/78388.png
#   inflating: /content/data/Images/Images/digit_7/78389.png
#   inflating: /content/data/Images/Images/digit_7/78390.png
#   inflating: /content/data/Images/Images/digit_7/78391.png
#   inflating: /content/data/Images/Images/digit_7/78392.png
#   inflating: /content/data/Images/Images/digit_7/78393.png
#   inflating: /content/data/Images/Images/digit_7/78394.png
#   inflating: /content/data/Images/Images/digit_7/78395.png
#   inflating: /content/data/Images/Images/digit_7/78396.png
#   inflating: /content/data/Images/Images/digit_7/78397.png
#   inflating: /content/data/Images/Images/digit_7/78398.png
#   inflating: /content/data/Images/Images/digit_7/78399.png
#   inflating: /content/data/Images/Images/digit_7/78400.png
#   inflating: /content/data/Images/Images/digit_7/78401.png
#   inflating: /content/data/Images/Images/digit_7/78402.png
#   inflating: /content/data/Images/Images/digit_7/78403.png
#   inflating: /content/data/Images/Images/digit_7/78404.png
#   inflating: /content/data/Images/Images/digit_7/78405.png
#   inflating: /content/data/Images/Images/digit_7/78406.png
#   inflating: /content/data/Images/Images/digit_7/78407.png
#   inflating: /content/data/Images/Images/digit_7/78408.png
#   inflating: /content/data/Images/Images/digit_7/78409.png
#   inflating: /content/data/Images/Images/digit_7/78410.png
#   inflating: /content/data/Images/Images/digit_7/78411.png
#   inflating: /content/data/Images/Images/digit_7/78412.png
#   inflating: /content/data/Images/Images/digit_7/78413.png
#   inflating: /content/data/Images/Images/digit_7/78414.png
#   inflating: /content/data/Images/Images/digit_7/78415.png
#   inflating: /content/data/Images/Images/digit_7/78416.png
#   inflating: /content/data/Images/Images/digit_7/78417.png
#   inflating: /content/data/Images/Images/digit_7/78418.png
#   inflating: /content/data/Images/Images/digit_7/78419.png
#   inflating: /content/data/Images/Images/digit_7/78420.png
#   inflating: /content/data/Images/Images/digit_7/78421.png
#   inflating: /content/data/Images/Images/digit_7/78422.png
#   inflating: /content/data/Images/Images/digit_7/78423.png
#   inflating: /content/data/Images/Images/digit_7/78424.png
#   inflating: /content/data/Images/Images/digit_7/78425.png
#   inflating: /content/data/Images/Images/digit_7/78426.png
#   inflating: /content/data/Images/Images/digit_7/78427.png
#   inflating: /content/data/Images/Images/digit_7/78428.png
#   inflating: /content/data/Images/Images/digit_7/78429.png
#   inflating: /content/data/Images/Images/digit_7/78430.png
#   inflating: /content/data/Images/Images/digit_7/78431.png
#   inflating: /content/data/Images/Images/digit_7/78432.png
#   inflating: /content/data/Images/Images/digit_7/78433.png
#   inflating: /content/data/Images/Images/digit_7/78434.png
#   inflating: /content/data/Images/Images/digit_7/78435.png
#   inflating: /content/data/Images/Images/digit_7/78436.png
#   inflating: /content/data/Images/Images/digit_7/78437.png
#   inflating: /content/data/Images/Images/digit_7/78438.png
#   inflating: /content/data/Images/Images/digit_7/78439.png
#   inflating: /content/data/Images/Images/digit_7/78440.png
#   inflating: /content/data/Images/Images/digit_7/78441.png
#   inflating: /content/data/Images/Images/digit_7/78442.png
#   inflating: /content/data/Images/Images/digit_7/78443.png
#   inflating: /content/data/Images/Images/digit_7/78444.png
#   inflating: /content/data/Images/Images/digit_7/78465.png
#   inflating: /content/data/Images/Images/digit_7/78466.png
#   inflating: /content/data/Images/Images/digit_7/78467.png
#   inflating: /content/data/Images/Images/digit_7/78468.png
#   inflating: /content/data/Images/Images/digit_7/78469.png
#   inflating: /content/data/Images/Images/digit_7/78470.png
#   inflating: /content/data/Images/Images/digit_7/78471.png
#   inflating: /content/data/Images/Images/digit_7/78472.png
#   inflating: /content/data/Images/Images/digit_7/78473.png
#   inflating: /content/data/Images/Images/digit_7/78474.png
#   inflating: /content/data/Images/Images/digit_7/78475.png
#   inflating: /content/data/Images/Images/digit_7/78476.png
#   inflating: /content/data/Images/Images/digit_7/78477.png
#   inflating: /content/data/Images/Images/digit_7/78478.png
#   inflating: /content/data/Images/Images/digit_7/78479.png
#   inflating: /content/data/Images/Images/digit_7/78480.png
#   inflating: /content/data/Images/Images/digit_7/78481.png
#   inflating: /content/data/Images/Images/digit_7/78482.png
#   inflating: /content/data/Images/Images/digit_7/78483.png
#   inflating: /content/data/Images/Images/digit_7/78484.png
#   inflating: /content/data/Images/Images/digit_7/78485.png
#   inflating: /content/data/Images/Images/digit_7/78486.png
#   inflating: /content/data/Images/Images/digit_7/78487.png
#   inflating: /content/data/Images/Images/digit_7/78488.png
#   inflating: /content/data/Images/Images/digit_7/78489.png
#   inflating: /content/data/Images/Images/digit_7/78490.png
#   inflating: /content/data/Images/Images/digit_7/78491.png
#   inflating: /content/data/Images/Images/digit_7/78492.png
#   inflating: /content/data/Images/Images/digit_7/78493.png
#   inflating: /content/data/Images/Images/digit_7/78494.png
#   inflating: /content/data/Images/Images/digit_7/78495.png
#   inflating: /content/data/Images/Images/digit_7/78496.png
#   inflating: /content/data/Images/Images/digit_7/78497.png
#   inflating: /content/data/Images/Images/digit_7/78498.png
#   inflating: /content/data/Images/Images/digit_7/78499.png
#   inflating: /content/data/Images/Images/digit_7/78500.png
#   inflating: /content/data/Images/Images/digit_7/78501.png
#   inflating: /content/data/Images/Images/digit_7/78502.png
#   inflating: /content/data/Images/Images/digit_7/78503.png
#   inflating: /content/data/Images/Images/digit_7/78504.png
# ...
#   inflating: /content/data/Images/Images/digit_9/91668.png
#   inflating: /content/data/Images/Images/digit_9/91669.png
#   inflating: /content/data/Images/Images/digit_9/91670.png
#   inflating: /content/data/Images/Images/digit_9/91671.png
#   inflating: /content/data/Images/Images/digit_9/91672.png
#   inflating: /content/data/Images/Images/digit_9/91673.png
#   inflating: /content/data/Images/Images/digit_9/91674.png
#   inflating: /content/data/Images/Images/digit_9/91675.png
#   inflating: /content/data/Images/Images/digit_9/92602.png
#   inflating: /content/data/Images/Images/digit_9/92603.png
#   inflating: /content/data/Images/Images/digit_9/92604.png
#   inflating: /content/data/Images/Images/digit_9/92605.png
#   inflating: /content/data/Images/Images/digit_9/92606.png
#   inflating: /content/data/Images/Images/digit_9/92607.png
#   inflating: /content/data/Images/Images/digit_9/92608.png
#   inflating: /content/data/Images/Images/digit_9/92609.png
#   inflating: /content/data/Images/Images/digit_9/92610.png
#   inflating: /content/data/Images/Images/digit_9/92611.png
#   inflating: /content/data/Images/Images/digit_9/92612.png
#   inflating: /content/data/Images/Images/digit_9/92613.png
#   inflating: /content/data/Images/Images/digit_9/92614.png
#   inflating: /content/data/Images/Images/digit_9/92615.png
#   inflating: /content/data/Images/Images/digit_9/92616.png
#   inflating: /content/data/Images/Images/digit_9/92617.png
#   inflating: /content/data/Images/Images/digit_9/92618.png
#   inflating: /content/data/Images/Images/digit_9/92619.png
#   inflating: /content/data/Images/Images/digit_9/92620.png
#   inflating: /content/data/Images/Images/digit_9/92621.png
#   inflating: /content/data/Images/Images/digit_9/92622.png
#   inflating: /content/data/Images/Images/digit_9/92623.png
#   inflating: /content/data/Images/Images/digit_9/92624.png
#   inflating: /content/data/Images/Images/digit_9/92625.png
#   inflating: /content/data/Images/Images/digit_9/99430.png
#   inflating: /content/data/Images/Images/digit_9/99431.png
#   inflating: /content/data/Images/Images/digit_9/99432.png
#   inflating: /content/data/Images/Images/digit_9/99433.png
#   inflating: /content/data/Images/Images/digit_9/99434.png
#   inflating: /content/data/Images/Images/digit_9/99435.png
#   inflating: /content/data/Images/Images/digit_9/99436.png
#   inflating: /content/data/Images/Images/digit_9/99437.png
#   inflating: /content/data/Images/Images/digit_9/99438.png
#   inflating: /content/data/Images/Images/digit_9/99439.png
#   inflating: /content/data/Images/Images/digit_9/99440.png
#   inflating: /content/data/Images/Images/digit_9/99441.png
#   inflating: /content/data/Images/Images/digit_9/99442.png
#   inflating: /content/data/Images/Images/digit_9/99443.png
#   inflating: /content/data/Images/Images/digit_9/99444.png
#   inflating: /content/data/Images/Images/digit_9/99445.png
#   inflating: /content/data/Images/Images/digit_9/99446.png
#   inflating: /content/data/Images/Images/digit_9/99447.png
#   inflating: /content/data/Images/Images/digit_9/99448.png
#   inflating: /content/data/Images/Images/digit_9/99449.png
#   inflating: /content/data/Images/Images/digit_9/99450.png
#   inflating: /content/data/Images/Images/digit_9/99451.png
#   inflating: /content/data/Images/Images/digit_9/99452.png
#   inflating: /content/data/Images/Images/digit_9/99453.png
#   inflating: /content/data/Images/Images/digit_9/99454.png
#   inflating: /content/data/Images/Images/digit_9/99455.png
#   inflating: /content/data/Images/Images/digit_9/99456.png
#   inflating: /content/data/Images/Images/digit_9/99457.png
#   inflating: /content/data/Images/Images/digit_9/99458.png
#   inflating: /content/data/Images/Images/digit_9/99459.png
#   inflating: /content/data/Images/Images/digit_9/99460.png
#   inflating: /content/data/Images/Images/digit_9/99461.png
#   inflating: /content/data/Images/Images/digit_9/99462.png
#   inflating: /content/data/Images/Images/digit_9/99463.png
#   inflating: /content/data/Images/Images/digit_9/99464.png
#   inflating: /content/data/Images/Images/digit_9/99465.png
#   inflating: /content/data/Images/Images/digit_9/99466.png
#   inflating: /content/data/Images/Images/digit_9/99467.png
#   inflating: /content/data/Images/Images/digit_9/99468.png
#   inflating: /content/data/Images/Images/digit_9/99469.png
#   inflating: /content/data/Images/Images/digit_9/99470.png
#   inflating: /content/data/Images/Images/digit_9/99471.png
#   inflating: /content/data/Images/Images/digit_9/99472.png
#   inflating: /content/data/Images/Images/digit_9/99473.png
#   inflating: /content/data/Images/Images/digit_9/99474.png
#   inflating: /content/data/Images/Images/digit_9/99475.png
#   inflating: /content/data/Images/Images/digit_9/99476.png
#   inflating: /content/data/Images/Images/digit_9/99477.png
#   inflating: /content/data/Images/Images/digit_9/99478.png
#   inflating: /content/data/Images/Images/digit_9/99479.png
#   inflating: /content/data/Images/Images/digit_9/99480.png
#   inflating: /content/data/Images/Images/digit_9/99481.png
#   inflating: /content/data/Images/Images/digit_9/99482.png
#   inflating: /content/data/Images/Images/digit_9/99483.png
#   inflating: /content/data/Images/Images/digit_9/99484.png
#   inflating: /content/data/Images/Images/digit_9/99485.png
#   inflating: /content/data/Images/Images/digit_9/99486.png
#   inflating: /content/data/Images/Images/digit_9/99487.png
#   inflating: /content/data/Images/Images/digit_9/99488.png
#   inflating: /content/data/Images/Images/digit_9/99489.png
#   inflating: /content/data/Images/Images/digit_9/99490.png
#   inflating: /content/data/Images/Images/digit_9/99491.png
#   inflating: /content/data/Images/Images/digit_9/99492.png
#   inflating: /content/data/Images/Images/digit_9/99493.png
#   inflating: /content/data/Images/Images/digit_9/99494.png
#   inflating: /content/data/Images/Images/digit_9/99495.png
#   inflating: /content/data/Images/Images/digit_9/99496.png
#   inflating: /content/data/Images/Images/digit_9/99497.png
#   inflating: /content/data/Images/Images/digit_9/99498.png
#   inflating: /content/data/Images/Images/digit_9/99499.png
#   inflating: /content/data/Images/Images/digit_9/99500.png
#   inflating: /content/data/Images/Images/digit_9/99641.png
#   inflating: /content/data/Images/Images/digit_9/99642.png
#   inflating: /content/data/Images/Images/digit_9/99643.png
#   inflating: /content/data/Images/Images/digit_9/99644.png
#   inflating: /content/data/Images/Images/digit_9/99645.png
#   inflating: /content/data/Images/Images/digit_9/99646.png
#   inflating: /content/data/Images/Images/digit_9/99647.png
#   inflating: /content/data/Images/Images/digit_9/99648.png
#   inflating: /content/data/Images/Images/digit_9/99649.png
#   inflating: /content/data/Images/Images/digit_9/99650.png
#   inflating: /content/data/Images/Images/digit_9/99651.png
#   inflating: /content/data/Images/Images/digit_9/99652.png
#   inflating: /content/data/Images/Images/digit_9/99653.png
#   inflating: /content/data/Images/Images/digit_9/99654.png
#   inflating: /content/data/Images/Images/digit_9/99655.png
#   inflating: /content/data/Images/Images/digit_9/99656.png
#   inflating: /content/data/Images/Images/digit_9/99657.png
#   inflating: /content/data/Images/Images/digit_9/99658.png
#   inflating: /content/data/Images/Images/digit_9/99659.png
#   inflating: /content/data/Images/Images/digit_9/99660.png
#   inflating: /content/data/Images/Images/digit_9/99661.png
#   inflating: /content/data/Images/Images/digit_9/99662.png
#   inflating: /content/data/Images/Images/digit_9/99663.png
#   inflating: /content/data/Images/Images/digit_9/99664.png
#   inflating: /content/data/Images/Images/digit_9/99665.png
#   inflating: /content/data/Images/Images/digit_9/99666.png
#   inflating: /content/data/Images/Images/digit_9/99667.png
#   inflating: /content/data/Images/Images/digit_9/99668.png
#   inflating: /content/data/Images/Images/digit_9/99669.png
#   inflating: /content/data/Images/Images/digit_9/99670.png
#   inflating: /content/data/Images/Images/digit_9/99671.png
#   inflating: /content/data/Images/Images/digit_9/99672.png
#   inflating: /content/data/Images/Images/digit_9/99673.png
#   inflating: /content/data/Images/Images/digit_9/99674.png
#   inflating: /content/data/Images/Images/digit_9/99675.png
#   inflating: /content/data/Images/Images/digit_9/99676.png
#   inflating: /content/data/Images/Images/digit_9/99677.png
#   inflating: /content/data/Images/Images/digit_9/99678.png
#   inflating: /content/data/Images/Images/digit_9/99679.png
#   inflating: /content/data/Images/Images/digit_9/99680.png
#   inflating: /content/data/Images/Images/digit_9/99681.png
#   inflating: /content/data/Images/Images/digit_9/99682.png
#   inflating: /content/data/Images/Images/digit_9/99683.png
#   inflating: /content/data/Images/Images/digit_9/99684.png
#   inflating: /content/data/Images/Images/digit_9/99685.png
#   inflating: /content/data/Images/Images/digit_9/99686.png
#   inflating: /content/data/Images/Images/digit_9/99687.png
#   inflating: /content/data/Images/Images/digit_9/99688.png
#   inflating: /content/data/Images/Images/digit_9/99689.png
#   inflating: /content/data/Images/Images/digit_9/99690.png
#   inflating: /content/data/Images/Images/digit_9/99691.png
#   inflating: /content/data/Images/Images/digit_9/99692.png
#   inflating: /content/data/Images/Images/digit_9/99693.png
#   inflating: /content/data/Images/Images/digit_9/99694.png
#   inflating: /content/data/Images/Images/digit_9/99695.png
#   inflating: /content/data/Images/Images/digit_9/99696.png
#   inflating: /content/data/Images/Images/digit_9/99697.png
#   inflating: /content/data/Images/Images/digit_9/99698.png
#   inflating: /content/data/Images/Images/digit_9/99699.png
#   inflating: /content/data/Images/Images/digit_9/99700.png
#   inflating: /content/data/Images/Images/digit_9/99701.png
#   inflating: /content/data/Images/Images/digit_9/99702.png
#   inflating: /content/data/Images/Images/digit_9/99703.png
#   inflating: /content/data/Images/Images/digit_9/99704.png
#   inflating: /content/data/Images/Images/digit_9/99705.png
#   inflating: /content/data/Images/Images/digit_9/99706.png
#   inflating: /content/data/Images/Images/digit_9/99707.png
#   inflating: /content/data/Images/Images/digit_9/99708.png
#   inflating: /content/data/Images/Images/digit_9/99729.png
#   inflating: /content/data/Images/Images/digit_9/99730.png
#   inflating: /content/data/Images/Images/digit_9/99731.png
#   inflating: /content/data/Images/Images/digit_9/99732.png
#   inflating: /content/data/Images/Images/digit_9/99733.png
#   inflating: /content/data/Images/Images/digit_9/99734.png
#   inflating: /content/data/Images/Images/digit_9/99735.png
#   inflating: /content/data/Images/Images/digit_9/99736.png
#   inflating: /content/data/Images/Images/digit_9/99737.png
#   inflating: /content/data/Images/Images/digit_9/99738.png
#   inflating: /content/data/Images/Images/digit_9/99739.png
#   inflating: /content/data/Images/Images/digit_9/99740.png
#   inflating: /content/data/Images/Images/digit_9/99741.png
#   inflating: /content/data/Images/Images/digit_9/99742.png
#   inflating: /content/data/Images/Images/digit_9/99743.png
#   inflating: /content/data/Images/Images/digit_9/99744.png
#   inflating: /content/data/Images/Images/digit_9/99745.png
#   inflating: /content/data/Images/Images/digit_9/99746.png
#   inflating: /content/data/Images/Images/digit_9/99747.png
#   inflating: /content/data/Images/Images/digit_9/99748.png
#   inflating: /content/data/Images/Images/digit_9/99749.png
#   inflating: /content/data/Images/Images/digit_9/99750.png
#   inflating: /content/data/Images/Images/digit_9/99751.png
#   inflating: /content/data/Images/Images/digit_9/99752.png
#   inflating: /content/data/Images/Images/digit_9/99753.png
#   inflating: /content/data/Images/Images/digit_9/99754.png
#   inflating: /content/data/Images/Images/digit_9/99755.png
#   inflating: /content/data/Images/Images/digit_9/99756.png
#   inflating: /content/data/Images/Images/digit_9/99757.png
#   inflating: /content/data/Images/Images/digit_9/99758.png
#   inflating: /content/data/Images/Images/digit_9/99759.png
#   inflating: /content/data/Images/Images/digit_9/99760.png
#   inflating: /content/data/Images/Images/digit_9/99761.png
#   inflating: /content/data/Images/Images/digit_9/99762.png
#   inflating: /content/data/Images/Images/digit_9/99763.png
#   inflating: /content/data/Images/Images/digit_9/99764.png
#   inflating: /content/data/Images/Images/digit_9/99765.png
#   inflating: /content/data/Images/Images/digit_9/99766.png
#   inflating: /content/data/Images/Images/digit_9/99767.png
#   inflating: /content/data/Images/Images/digit_9/99768.png
#   inflating: /content/data/Images/Images/digit_9/99769.png
#   inflating: /content/data/Images/Images/digit_9/99770.png
#   inflating: /content/data/Images/Images/digit_9/99771.png
#   inflating: /content/data/Images/Images/digit_9/99772.png
#   inflating: /content/data/Images/Images/digit_9/99773.png
#   inflating: /content/data/Images/Images/digit_9/99774.png
#   inflating: /content/data/Images/Images/digit_9/99775.png
#   inflating: /content/data/Images/Images/digit_9/99776.png
#   inflating: /content/data/Images/Images/digit_9/99777.png
#   inflating: /content/data/Images/Images/digit_9/99778.png
#   inflating: /content/data/Images/Images/digit_9/99779.png
#   inflating: /content/data/Images/Images/digit_9/99780.png
#   inflating: /content/data/Images/Images/digit_9/99781.png
#   inflating: /content/data/Images/Images/digit_9/99782.png
#   inflating: /content/data/Images/Images/digit_9/99783.png
#   inflating: /content/data/Images/Images/digit_9/99784.png
#   inflating: /content/data/Images/Images/digit_9/99785.png
#   inflating: /content/data/Images/Images/digit_9/99786.png
#   inflating: /content/data/Images/Images/digit_9/99787.png
#   inflating: /content/data/Images/Images/digit_9/99788.png
#   inflating: /content/data/Images/Images/digit_9/99789.png
#   inflating: /content/data/Images/Images/digit_9/99790.png
#   inflating: /content/data/Images/Images/digit_9/99791.png
#   inflating: /content/data/Images/Images/digit_9/99792.png
#   inflating: /content/data/Images/Images/digit_9/99793.png
#   inflating: /content/data/Images/Images/digit_9/99794.png
#   inflating: /content/data/Images/Images/digit_9/99795.png
#   inflating: /content/data/Images/Images/digit_9/99796.png
#   inflating: /content/data/Images/Images/digit_9/99797.png
#   inflating: /content/data/Images/Images/digit_9/99798.png
#   inflating: /content/data/Images/Images/digit_9/99799.png
#   inflating: /content/data/Images/Images/digit_9/99800.png
#   inflating: /content/data/Images/Images/digit_9/99801.png
#   inflating: /content/data/Images/Images/digit_9/99802.png
#   inflating: /content/data/Images/Images/digit_9/99803.png
#   inflating: /content/data/Images/Images/digit_9/99804.png
#   inflating: /content/data/Images/Images/digit_9/99805.png
#   inflating: /content/data/Images/Images/digit_9/99806.png
#   inflating: /content/data/Images/Images/digit_9/99807.png
#   inflating: /content/data/Images/Images/digit_9/99808.png
#   inflating: /content/data/Images/Images/digit_9/99809.png
#   inflating: /content/data/Images/Images/digit_9/99810.png
#   inflating: /content/data/Images/Images/digit_9/99811.png
#   inflating: /content/data/Images/Images/digit_9/99812.png
#   inflating: /content/data/Images/Images/digit_9/99813.png
#   inflating: /content/data/Images/Images/digit_9/99814.png
#   inflating: /content/data/Images/Images/digit_9/99815.png
#   inflating: /content/data/Images/Images/digit_9/99816.png
#   inflating: /content/data/Images/Images/digit_9/99817.png
#   inflating: /content/data/Images/Images/digit_9/99818.png
#   inflating: /content/data/data.csv

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
def crop_images(dataset):
    # Calculating start and end indices for the crop
    start = (32 - 28) // 2  # (32 - 28) / 2 = 2
    end = start + 28  # 2 + 28 = 30

    # Cropping to get 28x28 images
    #dataset[:, start:end, start:end] would be the sliced tensor
    dataset_out=torch.zeros(92000,28,28)
    #print(dataset.shape[0])

    for i in range(dataset.shape[0]):
      dataset_out=dataset[:, start:end, start:end]
#      print(dataset[i].shape, " ", dataset[i].numpy())

    return dataset_out #dataset[:, start:end, start:end]

# import torch
# from PIL import Image
# import torchvision.transforms.functional as TF

# # Assume `images` is your tensor with shape [100, 32, 32]
# images = torch.randn(100, 32, 32)  # Example tensor

# def crop_images(tensor_images):
#     new_size=(28, 28)
#     resized_images = []
#     for img_tensor in tensor_images:
#         # Convert the tensor to a PIL image
#         img_pil = TF.to_pil_image(img_tensor)

#         # Resize the image using Pillow
#         img_pil = img_pil.resize(new_size, Image.NEAREST)

#         # Convert the PIL image back to a tensor
#         img_tensor_resized = TF.to_tensor(img_pil)

#         # Append the resized tensor to the list
#         resized_images.append(img_tensor_resized)
#     #print(resized_images.shape)
#     # Stack all resized image tensors back into a single tensor
#     return torch.stack(resized_images)

# %%
import pandas as pd
import torch
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Subset
from torch.utils.data import DataLoader, random_split, Subset
from torchvision import transforms
from torch import nn

# Load the CSV file
data = pd.read_csv('/content/data/data.csv')

# Convert all columns to numeric, coercing errors and handling non-numeric data
#data = data.apply(pd.to_numeric, errors='coerce')


# Fill NaN values with 0 (consider other strategies depending on your context)
#data = data.fillna(0)

# Assume images are 28x28 pixels, update this based on your actual image dimensions
image_height = 32
image_width = 32

# Separate features and labels
features = data.iloc[:, :-1]  # All rows, all columns except the last one
features.head()
# column_sums = features.sum()
# print(column_sums)

# Fill missing values if any
#features = features.fillna(0)

features_images = features.values.reshape(-1, 32, 32)
labels = data.iloc[:, -1]     # All rows, only the last column

label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)


# Convert to PyTorch tensors
features_tensor = torch.tensor(features_images, dtype=torch.float32)
# Cropping the images
cropped_features_tensor = crop_images(features_tensor)
cropped_features_tensor=cropped_features_tensor.squeeze(1)
labels_tensor = torch.tensor(labels_encoded, dtype=torch.long)

print("cropped features", cropped_features_tensor.shape)
# Resize all images
#resized_images = torch.stack([resize_image(img) for img in features_tensor])
#resized_images_squeezed=resized_images.squeeze(1)
#print("resized_tensor", resized_images_squeezed.shape)

# Convert DataFrame to PyTorch tensors
# features_tensor = torch.tensor(features.values, dtype=torch.float32)
# labels_tensor = torch.tensor(labels.values, dtype=torch.long)

# Create a TensorDataset to be used with a DataLoader
dataset = TensorDataset(cropped_features_tensor, labels_tensor)
#dataset = TensorDataset(features_tensor, labels_tensor)

# Generate a random permutation of indices and select the first 1000
indices = torch.randperm(len(dataset))[:10000]

# Create a subset with these indices
subset = Subset(dataset, indices)

# Split the subset into training and testing datasets (80-20 or 70: 30 split)
num_train = int(0.7 * len(subset))  # 80% for training
num_test = len(subset) - num_train  # Remaining 20% for testing

train_dataset, test_dataset = random_split(subset, [num_train, num_test])
# def reshape_dataset(dataset, new_shape):
#     reshaped_features = [features.view(new_shape) for features, _ in dataset]
#     labels = [labels for _, labels in dataset]
#     features_tensor = torch.stack(reshaped_features)
#     labels_tensor = torch.stack(labels)
#     return TensorDataset(features_tensor, labels_tensor)

# # Reshape the datasets to 32x32
# train_dataset_reshaped = reshape_dataset(train_dataset, (-1, 32, 32))
# test_dataset_reshaped = reshape_dataset(test_dataset, (-1, 32, 32))

# Create DataLoaders for train and test sets
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# Example usage
# for features, labels in train_loader:
#     # Training loop code here
#     print("Training batch features:", features.size())
#     print("Training batch labels:", labels.size())

# for features, labels in test_loader:
#     # Testing loop code here
    # print("Testing batch features:", features.size())
    # print("Testing batch labels:", labels.size())

# Create a DataLoader to handle batching
#dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
# Out:
# cropped features torch.Size([92000, 28, 28])

# %%
# Plotting function
def plot_images(images, labels, num_images=5):
  fig, axes = plt.subplots(1, num_images, figsize=(10, 2))
  for i, ax in enumerate(axes):
    ax.imshow(images[i], cmap='gray')
    ax.set_title(f'Label: {labels[i]}')
    ax.axis('on')
  plt.show()

# Display the first 5 images and labels
for features, labels in train_loader:
  plot_images(features, labels, 5)
  break  # Only process the first batch#

# %%
for features, labels in train_loader:
  print(features.shape)
# Out:
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([64, 28, 28])
# torch.Size([24, 28, 28])

# %%
from torch.utils.data import TensorDataset
from IPython.display import display, clear_output
import time


def plot_images_by_label(dataloader, specific_label, num_images=5):
    count = 0  # Counter to track how many images we have displayed
    plt.figure(figsize=(10, 2))  # Set up the figure size

    for images, labels in dataloader:
        for image, label in zip(images, labels):
            if label.item() == specific_label:  # Check if the label matches
                count += 1
                ax = plt.subplot(1, num_images, count)  # Create a subplot for each image
                ax.imshow(image.squeeze(), cmap='gray')  # Display image, squeeze() is used to remove extra dimensions if any
                ax.title.set_text(f'Label: {label.item()}')
                ax.axis('on')  # Turn off axis

                if count == num_images:  # Only display a specific number of images
                    plt.show()
                    return
# Example usage
# Assuming your DataLoader, images, and labels are properly set up
# Here you call the function with the label you want to display and the number of images

for i in range(2):
  plot_images_by_label(train_loader, specific_label=i, num_images=5)# Call the function with the desired label
  clear_output(wait=True)  # Clear the current output and wait for new output
  time.sleep(0.01)  # Pause for a second to simulate time taken in an iteration

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"    # Get gpu or cpu device for training
print(f"Using {device} device\n")

import torchvision.transforms.functional as TF
from skimage.feature import hog
from quantum_circuit_simulator import quantum_circuit


# Define a function to compute HOG features for an image
def compute_hog_features(image):
    features, _ = hog(image, orientations=12, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)

    return features

#=====================================================================================


class QNN(torch.nn.Module):                              # Define model
    def __init__(self, n, L):                            # number of qubits = n, number of quantum layers = L
        super().__init__()

        self.flatten = nn.Flatten()

        angles = torch.empty((L, n), dtype=torch.float64)
        torch.nn.init.uniform_(angles, -0.01, 0.01)
        self.angles = torch.nn.Parameter(angles)                   # it makes angles learnable parameters

        # self.fc1 = nn.Linear(1024, 1024)
        # self.fc2 = nn.Linear(784,512)
        # self.fc3 = nn.Linear(512, 1024)

        self.linear1 = nn.Linear(2**n, 256)                          # classical linear layer
        self.linear2 = nn.Linear(256,46)                          # classical linear layer


    def forward(self, x):
        #x = F.pad(x, (2 ,2, 2, 2), "constant", 0)                  # (left, right, top, bottom) padding
        x_projection = torch.sum(x, dim=1).to(device)  # Calculate x-axis projection
        #x_projection = x_projection / torch.norm(x_projection, p=1)
        #print("x projection ",x_projection.shape)
        y_projection = torch.sum(x, dim=2).to(device)  # Calculate x-axis projection
        #print("y projection ",y_projection.shape)
        #y_projection = y_projection / torch.norm(y_projection, p=1)
        #angle projection
        rotated_images1 = TF.rotate(x,30).to(device)
        rotated_images2 = TF.rotate(x,45).to(device)
        rotated_images3 = TF.rotate(x,60).to(device)

        #rotated projections
        rotated_projection1=torch.sum(rotated_images1, dim=2).to(device)
        rotated_projection2=torch.sum(rotated_images2, dim=2).to(device)
        rotated_projection3=torch.sum(rotated_images3, dim=2).to(device)

        #rotated_images = torch.sum(torch.stack([TF.rotate(img, angle) for img in inputs]))
        x_image=x.cpu().numpy()
        hog_features = [compute_hog_features(np.squeeze(image)) for image in x_image]
        hog_features_tensor = torch.tensor(np.array(hog_features), dtype=torch.float32).to(device)
        #print(hog_features_tensor.shape)

        x = self.flatten(x)
        x = x[:, :-92]

        # print("sizes ",x.shape, y_projection.shape, rotated_projection1.shape,rotated_projection2.shape,
        #      rotated_projection3.shape,hog_features_tensor.shape)

        combined_projection=torch.cat((x,x_projection,y_projection, rotated_projection1,rotated_projection2,rotated_projection3,#rotated_projection4.squeeze(),rotated_projection5.squeeze(),rotated_projection6.squeeze(),
                                       hog_features_tensor), dim=1)
        #print(x.shape, " ",hog_features_tensor.shape)
        #torch.zeros(x.shape[0],100).to(device)
        #print("combined ", combined_projection.shape)
        #x = self.flatten(x)
        combined_projection /= torch.linalg.norm(x.clone(), ord=2, dim=1, keepdim=True)   # L2 normalization to change x --> |x⟩

        # combined_projection = torch.sigmoid(self.fc1(combined_projection))
        # x1 = torch.sigmoid(self.fc2(x1))
        # x1 = torch.sigmoid(self.fc3(x1))

        '''initializing parameterized quantum circuits (PQC)'''

        qc = quantum_circuit(num_qubits = n, state_vector = combined_projection.T)   # each column is a feature-vector of an example
        for l in range(L):
            qc.Ry_layer(self.angles[l].to(torch.cfloat))           # rotation part of lth quantum layer
            qc.cx_linear_layer()                                   # entangling part of lth quantum layer

        'after passing through the PQC, measurement on the output-ket in the computational basis'
        x = torch.real(qc.probabilities())               # each column is a probabilities-vector for an example
                                                         # x.shape = (dim, batch size)

        #print(torch.sum(x, dim=0))                      # to see whether probabilities add up to 1 or not

        x = self.linear1(x.T)                            # x.shape = (batch size, 10),  classical linear layer
        x= self.linear2(x)
        return x
# Out:
# Using cpu device

# %%
def performance_estimate(dataset, model, loss_fn, train_or_test):
    '''this function computes accuracy and loss of a model on the training or test set'''
    data_size = len(dataset)

    dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
    num_batches = len(dataloader)

    model.eval()
    loss, accuracy = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            accuracy += (pred.argmax(1) == y).sum().item()
            loss += loss_fn(pred, y).item()
    accuracy /= data_size                                            # accuracy lies in the interval [0, 1]
    loss /= num_batches
    print(f"{train_or_test} accuracy: {round(accuracy, 3)},  {train_or_test} loss: {round(loss,3)}")
    return accuracy, loss




def one_epoch(model, loss_fn, optimizer, train_dataset, test_dataset, batch_size):

    A_train, L_train, A_test, L_test = [], [], [], []

    dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        out = model(X)                             # Perform a single forward pass
        loss = loss_fn(out, y)

        optimizer.zero_grad()                      # Clear gradients
        loss.backward()                            # Derive gradients, backpropagation
        optimizer.step()                           # Update parameters based on gradients


        if batch % batch_size == 0:
            #As training progress, computing and appending loss and accuracy of the model on train and test set
            accuracy_train, loss_train = performance_estimate(train_dataset, model, loss_fn, 'train')
            accuracy_test, loss_test = performance_estimate(test_dataset, model, loss_fn, 'test ')
            print()

            A_train.append(accuracy_train)
            L_train.append(loss_train)
            A_test.append(accuracy_test)
            L_test.append(loss_test)

            #print(f"train loss: {round(loss,3)}")

    return A_train, L_train, A_test, L_test



def training(train_dataset, test_dataset, batch_size, n, L, lr_, weight_decay_, epochs):

    model = QNN(n=n, L=L).to(device)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr_, weight_decay=weight_decay_)

    A_Train, L_Train, A_Test, L_Test = [], [], [], []
    for t in range(epochs):
        print(f"Epoch {t+1} ---------------------------------- \n")
        #As training progress, computing and appending loss and accuracy of the model on train and test set
        A_train, L_train, A_test, L_test = one_epoch(model, loss_fn, optimizer, train_dataset, test_dataset, batch_size)
        A_Train += A_train
        L_Train += L_train
        A_Test += A_test
        L_Test += L_test

        #accuracy, loss = performance_estimate(test_dataset, model, loss_fn, 'test ')

    model_state_dict = model.state_dict()           # for saving or loading the trained model

    return A_Train, L_Train, A_Test, L_Test, model_state_dict

# %%
# %%time

n = 10
dim = 2**n              # dimension of the n-qubit Hilbert space
L = 3

n_angs = n*L

print("number of qubits = ", n)
print("number of quantum layers = ", L)
print(f"number of angles (learnable parameters of quantum circuit) = {n_angs}\n ")

#--------------------------------------------------------------------------------------


batch_size = 64
print(f'batch_size = {batch_size}\n')


#----------------------------------------------------------------------------------


A_Train, L_Train, A_Test, L_Test, model_state_dict = training(train_dataset, test_dataset, batch_size=batch_size, n=n, L=L,
                                                              lr_=0.01/10, weight_decay_=1e-10, epochs=100)


print(f' ~~~~~ training is done ~~~~~\n')
# Out:
# number of qubits =  10
# number of quantum layers =  3
# number of angles (learnable parameters of quantum circuit) = 30
#
# batch_size = 64
#
# Epoch 1 ----------------------------------
#
# train accuracy: 0.035,  train loss: 3.818
# test  accuracy: 0.038,  test  loss: 3.818
#
# train accuracy: 0.394,  train loss: 2.698
# test  accuracy: 0.367,  test  loss: 2.747
#
# Epoch 2 ----------------------------------
#
# train accuracy: 0.482,  train loss: 2.142
# test  accuracy: 0.453,  test  loss: 2.231
#
# train accuracy: 0.536,  train loss: 1.802
# test  accuracy: 0.501,  test  loss: 1.909
#
# Epoch 3 ----------------------------------

# %%
plt.plot(A_Train, label='train set')
plt.plot(A_Test, label='test set')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.plot(L_Train, label='train set')
plt.plot(L_Test, label='test set')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
idx = np.random.choice(len(test_dataset))

x = test_dataset[idx][0]
print(f'x of {x.shape} :')
plt.imshow(x[0], cmap='gray')
plt.show()

print(f'true label = y = {test_dataset[idx][1]}\n')


out_ = model(x.view(1, 1, 28, 28)).detach().flatten()
prob = F.softmax(out_, dim=0)
pred = prob.argmax().item()
print(f'predicted label = {pred}\n')

plt.stem(np.arange(10), prob)
plt.ylabel('probability')
plt.xlabel('class labels')
plt.show()

# %%
2048-1896
