# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishar/q_character/blob/main/Ranjana_with_qnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchvision
# !pip install qiskit-machine-learning
import importlib

# Check if torchvision is installed
try:
    importlib.import_module('torchvision')
    print("torchvision is already installed.")
except ImportError:
    print("torchvision is not installed. Installing...")
    # Install torchvision using pip
    try:
        import pip
        pip.main(['install', 'torchvision'])
        print("torchvision installed successfully.")
    except Exception as e:
        print("Error occurred while installing torchvision:", str(e))

# try:
#     importlib.import_module('qiskit')
#     print("qiskit is already installed.")
# except ImportError:
#     print("qiskit is not installed. Installing...")
#     # Install torchvision using pip
#     try:
#         import pip
#         pip.main(['install', 'qiskit'])
#         print("qiskit installed successfully.")
#     except Exception as e:
#         print("Error occurred while installing qiskit:", str(e))

# try:
#     importlib.import_module('qiskit_machine_learning')
#     print("qiskit-machine-learning is already installed.")
# except ImportError:
#     print("qiskit-machine-learning is not installed. Installing...")
#     # Install torchvision using pip
#     try:
#         import pip
#         pip.main(['install', 'qiskit-machine-learning'])
#         print("qiskit-machine-learning installed successfully.")
#     except Exception as e:
#         print("Error occurred while installing qiskit-machine-learning:", str(e))
# Out:
# torchvision is already installed.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Change directory to the desired location where the file is stored.
# %cd /content/drive/MyDrive/

# Import the file named quantum_circuit_simulator.py
#import quantum_circuit_simulator
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive

# %%
import torch
import math



def get_device(gpu_no):
    if torch.cuda.is_available():
        return torch.device('cuda', gpu_no)
    else:
        return torch.device('cpu')






class quantum_circuit:

    def __init__(self, num_qubits : int, state_vector = None, device = 'cuda', gpu_no = 0):

        """
        Defines a quantum circuit object that stores the full state-vector (evolved through
        the unitary operations of a quantum circuit) of `num_qubits` number of qubits.

        Args:
            num_qubits (int): Number of qubits in the circuit.

            state_vector (torch.Tensor, optional): The full state vector of the quantum circuit.
                                          Defaults to None. If None is provided then the state
                                          vector is automatically initialized to the ket |0000...0>.

            device (str, optional): Device on which the state vector should be stored (CPU / GPU).
                                    Defaults to 'cuda' i.e. GPU.

            gpu_no (int, optional): If there are multiple GPUs then this parameter defines which
                                    GPU to use. Defaults to 0 i.e. the first device.
        """
        #----------------------------------------------------------------------------------------

        if device != 'cuda':
            self.device = torch.device(device)
        else:
            self.device = get_device(gpu_no)


        #----------------------------------------------------------------------------------------


        self.n = num_qubits   # number of qubits
        self.dim = 2**self.n  # dimention of the n-qubit hilbert space


        #----------------------------------------------------------------------------------------

        '''
        state_vector can
        (1) either be a vector of shape (dim,)
        (2) either be a matrix of shape (dim, number of examples)
        '''

        if state_vector is None:
            ''' Initialize the state-vector to |0000...0> '''
            state_vector = torch.zeros(self.dim, device=self.device, dtype=torch.cfloat)
            state_vector[0] = 1
            self.state_vector = state_vector.reshape(-1,1)
        else:
            if state_vector.shape[0] == self.dim:
                ''' state_vector must be normalized '''
                self.state_vector = state_vector.to(torch.cfloat)
            else:
                print('The dimension 2**n does NOT match the shape of the state vector. n is the number of qubits.')


        #----------------------------------------------------------------------------------------

        # single qubit Pauli gates (matrices) :
        self.I        = torch.tensor([[1,   0], [0,  1]], device=self.device, dtype=torch.cfloat)
        self.x_matrix = torch.tensor([[0.,  1], [1,  0]], device=self.device, dtype=torch.cfloat)
        self.y_matrix = torch.tensor([[0, -1j], [1j, 0]], device=self.device, dtype=torch.cfloat)
        self.z_matrix = torch.tensor([[1,   0], [0, -1]], device=self.device, dtype=torch.cfloat)

        self.h_matrix = (1 / math.sqrt(2)) * torch.tensor([[1, 1], [1, -1]], device=self.device, dtype=torch.cfloat)


        # single qubit projectors :
        self.proj_0 = torch.tensor([[1, 0], [0, 0]], device=self.device, dtype=torch.cfloat)
        self.proj_1 = torch.tensor([[0, 0], [0, 1]], device=self.device, dtype=torch.cfloat)



   #======================================================================================================



    def single_qubit_gate(self, target : int, gate : torch.Tensor):
        """
        Applies a single qubit gate = I ⊗ I ⊗ ... ⊗ gate ⊗ ... ⊗ I

        Args:
        target (int): The qubit index on which the gate will be applied
        gate (torch.Tensor): The matrix representation of a single qubit gate

        Returns:
        The state vector of the full quantum circuit after applying the single qubit gate.

        """

        if target < 0 or self.n <= target:
            print('0 <= traget <= num_qubits - 1 is NOT satisfied!')

        else:
            single_q_gate = torch.tensor(1, device=self.device, dtype=torch.cfloat) # initialize

            for k in range(self.n):
                if k == target:
                    single_q_gate = torch.kron(single_q_gate, gate)
                else:
                    single_q_gate = torch.kron(single_q_gate, self.I)

            #------------------------------------------------------

            self.state_vector = torch.matmul(single_q_gate, self.state_vector)
            return self.state_vector




    def controlled_gate(self, control: int, target: int, gate : torch.Tensor):
        """
        Applies a two-qubit controlled gate between the 'control` and `target` qubits.

        control_gate_part_0 = I ⊗ |0><0| ⊗ ... ⊗ I    ⊗ ... ⊗ I
        control_gate_part_1 = I ⊗ |1><1| ⊗ ... ⊗ gate ⊗ ... ⊗ I         SEE: the control is set to 1

        control_gate = control_gate_part_0 + control_gate_part_1


        Args:
        control (int): Control qubit index
        target (int):  Target qubit index
        gate (torch.Tensor): The matrix representation of a single qubit gate

        Returns:
        The state vector of the full quantum circuit after applying the two-qubit gate.
        """

        if control < 0 or self.n <= control:
            print('0 <= control <= num_qubits - 1 is NOT satisfied!')
        elif target < 0 or self.n <= target:
            print('0 <= target <= num_qubits - 1 is NOT satisfied!')
        elif control == target:
            print('control and traget qubits must be different!')
        else:
            control_gate_part_0 = torch.tensor(1, device=self.device, dtype=torch.cfloat) # initialize
            control_gate_part_1 = torch.tensor(1, device=self.device, dtype=torch.cfloat)

            for k in range(self.n):
                if k == control:
                    control_gate_part_0 = torch.kron(control_gate_part_0, self.proj_0)
                    control_gate_part_1 = torch.kron(control_gate_part_1, self.proj_1)
                elif k == target:
                    control_gate_part_0 = torch.kron(control_gate_part_0, self.I)
                    control_gate_part_1 = torch.kron(control_gate_part_1, gate)
                else:
                    control_gate_part_0 = torch.kron(control_gate_part_0, self.I)
                    control_gate_part_1 = torch.kron(control_gate_part_1, self.I)

            control_gate = control_gate_part_0 + control_gate_part_1

            self.state_vector = torch.matmul(control_gate, self.state_vector)
            return self.state_vector


    #======================================================================================================

    def x(self, target : int):                           # Applies X gate (matrix) on the target qubit
        'NOTE: 0 <= target <= num_qubits - 1'
        self.single_qubit_gate(target, self.x_matrix)


    def y(self, target : int):
        self.single_qubit_gate(target, self.y_matrix)


    def z(self, target : int):
        self.single_qubit_gate(target, self.z_matrix)


    def h(self, target : int):                           # Applies Hadamard gate (matrix) on the target qubit
        self.single_qubit_gate(target, self.h_matrix)


   #======================================================================================================


    def Rx(self, target : int, theta):

        """
        Applies Rx gate (rotation around x axis) on the target qubit

        Args:
        theta (torch.Tensor): Angle by which the qubit should be rotated around X axis.
                              Usually a tunable parameter is passed.

        target (int): Qubit index on which the Rx gate will be applied.
        NOTE: 0 <= target <= num_qubits - 1
        """

        co = torch.cos(theta / 2)
        si = torch.sin(theta / 2)
        self.Rx_matrix = torch.stack([torch.stack([co, -1j*si]), torch.stack([-1j*si, co])])

        self.single_qubit_gate(target, self.Rx_matrix)




    def Ry(self, target : int, theta):            #like Rx, Ry gate applies (rotation around y axis) on the target qubit

        co = torch.cos(theta / 2)
        si = torch.sin(theta / 2)
        self.Ry_matrix = torch.stack([torch.stack([co, -si]), torch.stack([si, co])])

        self.single_qubit_gate(target, self.Ry_matrix)





    def Rz(self, target : int, theta):            #like Rx, Ry gate applies (rotation around z axis) on the target qubit

        exp_theta = torch.exp( 1j*theta )
        zero = torch.tensor(0)
        one = torch.tensor(1)
        self.Rz_matrix = torch.stack([torch.stack([one, zero]), torch.stack([zero, exp_theta])])

        self.single_qubit_gate(target, self.Rz_matrix)




    def R(self, target : int, theta, phi, lamda):
        """
        Applies general rotation to the target qubit

        Args:
        theta, phi and lamda (torch.Tensor): The Euler angles which define a general rotation around Bloch sphere.

        target (int): Qubit index on which the gate will be applied.
        """

        a =                                  torch.cos(theta / 2)
        b =        - torch.exp(1j * lamda) * torch.sin(theta / 2)
        c =            torch.exp(1j * phi) * torch.sin(theta / 2)
        d =  torch.exp(1j * (phi + lamda)) * torch.cos(theta / 2)
        self.R_matrix = torch.stack([torch.stack([a, b]), torch.stack([c, d])])

        self.single_qubit_gate(target, self.R_matrix)


    #======================================================================================================


    def Ry_layer(self, angs: torch.Tensor):
        '''
        Applies tensor-product of single-qubit rotations around y-axis
        '''

        cos, sin = torch.cos(angs[0]), torch.sin(angs[0])
        '''
        Use torch.stack otherwise computation graph will be broken (or will not begin).
        And, grad will be gone (will not be stored).
        '''
        rot = torch.stack([torch.stack([cos, -sin]), torch.stack([sin, cos])])

        for i in range(1, len(angs)):                                    # one angles for each qubit
            cos, sin = torch.cos(angs[i]), torch.sin(angs[i])
            rot = torch.kron(rot, torch.stack([torch.stack([cos, -sin]), torch.stack([sin, cos])]))

        #--------------------------------------------------------------------------

        self.state_vector = torch.matmul(rot, self.state_vector)      # rotated state vector
        return self.state_vector





    def Rz_layer(self, angs: torch.Tensor):       #like Ry_layer, Rz_layer acts

        exp_ang = torch.exp( 1j*angs[0] )
        zero = torch.tensor(0)
        one = torch.tensor(1)

        rot = torch.stack([torch.stack([one, zero]), torch.stack([zero, exp_ang])])

        for i in range(1, len(angs)):                                    # one angles for each qubit
            exp_ang = torch.exp( 1j*angs[i] )
            rot = torch.kron(rot, torch.stack([torch.stack([one, zero]), torch.stack([zero, exp_ang])]) )

        #--------------------------------------------------------------------------

        self.state_vector = torch.matmul(rot, self.state_vector)      # rotated state vector
        return self.state_vector



    #======================================================================================================

    def cx(self, control: int, target: int):
        """
        Applies controlled-X gate = I ⊗ |0><0| ⊗ ... ⊗ I ⊗ ... ⊗ I +
                                    I ⊗ |1><1| ⊗ ... ⊗ X ⊗ ... ⊗ I

        Args:
        control (int): Control qubit index
        target (int):  Target qubit index
        """
        self.controlled_gate(control, target, self.x_matrix)




    def cz(self, control: int, target: int):                           #like cx, cz gate acts
        self.controlled_gate(control, target, self.z_matrix)



   #======================================================================================================


    def cx_linear_layer(self):
        '''
        Applies cx(n-1,n) ... cx(2,3) cx(1,2) cx(0,1) |state_vector>

        NOTE: First cx(0,1) will act on |state_vector>, then cx(1,2)
              And in the last cx(n-1,n) will act.
              order matter in case of cx
        '''

        self.controlled_gate(self.n - 2, self.n - 1, self.x_matrix)
        for i in range(self.n - 3, -1, -1):
            self.controlled_gate(i, i+1, self.x_matrix)



    def cz_linear_layer(self):                                        #like cx_linear_layer, cz_linear_layer  acts
        self.controlled_gate(self.n - 2, self.n - 1, self.z_matrix)
        for i in range(self.n - 3, -1, -1):
            self.controlled_gate(i, i+1, self.z_matrix)


   #======================================================================================================

    def probabilities(self):
        """
        probabilities obtained in the z-measurement (computational basis) on the state vector

        Returns: A torch.Tensor of the size same as the state vector
        """

        return self.state_vector.conj() * self.state_vector

# %%
# prompt: I want to download devanagari character dataset from Kaggle.
#!pip install kaggle
#!mkdir -p ~/.kaggle
#!cp /content/drive/MyDrive/ranjana/kaggle.json ~/.kaggle/kaggle.json
#!kaggle datasets download --force -d jenbati/ranjana-script-64
# !unzip "/content/drive/My Drive/ranjana/ranjana-script-64.zip" -d "/content/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (135).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (136).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (137).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (138).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (139).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (14).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (140).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (141).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (142).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (143).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (144).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (145).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (146).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (147).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (148).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (149).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (15).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (150).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (151).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (152).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (153).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (154).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (155).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (156).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (157).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (158).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (159).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (16).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (160).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (161).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (162).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (163).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (164).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (165).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (166).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (167).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (168).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (169).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (17).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (170).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (171).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (172).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (173).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (174).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (175).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (176).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (177).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (178).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (179).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (18).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (180).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (181).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (182).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (183).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (184).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (185).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (186).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (187).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (188).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (189).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (19).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (190).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (191).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (192).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (193).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (194).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (195).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (196).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (197).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (198).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (199).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (2).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (20).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (200).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (201).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (202).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (203).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (204).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (205).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (206).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (207).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (208).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (209).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (21).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (210).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (211).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (212).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (213).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (214).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (215).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (216).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (217).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (218).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (219).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (22).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (220).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (221).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (222).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (223).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (224).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (225).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (226).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (227).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (228).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (229).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (23).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (230).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (231).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (232).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (233).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (234).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (235).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (236).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (237).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (238).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (239).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (24).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (240).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (241).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (242).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (243).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (244).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (245).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (246).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (247).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (248).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (249).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (25).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (250).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (251).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (252).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (253).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (254).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (255).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (256).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (257).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (258).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (259).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (26).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (260).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (261).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (262).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (263).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (264).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (265).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (266).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (267).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (268).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (269).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (27).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (270).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (271).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (272).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (273).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (274).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (275).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (276).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (277).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (278).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (279).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (28).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (280).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (281).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (282).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (283).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (284).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (285).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (286).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (287).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (288).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (289).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (29).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (290).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (291).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (292).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (293).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (294).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (295).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (296).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (297).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (298).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (299).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (3).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (30).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (300).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (301).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (302).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (303).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (304).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (305).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (306).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (307).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (308).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (309).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (31).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (310).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (311).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (312).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (313).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (314).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (315).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (316).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (317).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (318).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (319).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (32).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (320).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (321).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (322).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (323).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (324).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (325).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (326).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (327).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (328).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (329).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (33).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (330).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (331).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (332).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (333).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (334).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (335).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (336).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (337).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (338).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (339).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (34).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (340).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (341).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (342).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (343).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (344).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (345).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (346).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (347).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (348).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (349).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (35).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (350).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (351).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (352).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (353).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (354).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (355).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (356).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (357).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (358).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (359).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (36).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (360).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (361).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (362).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (363).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (364).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (365).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (366).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (367).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (368).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (369).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (37).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (370).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (371).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (372).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (373).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (374).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (375).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (376).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (377).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (378).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (379).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (38).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (380).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (381).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (382).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (383).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (384).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (385).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (386).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (387).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (388).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (389).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (39).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (390).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (391).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (392).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (393).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (394).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (395).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (396).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (397).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (398).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (399).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (4).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (40).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (400).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (401).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (402).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (403).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (404).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (405).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (406).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (407).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (408).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (409).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (41).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (410).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (411).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (412).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (413).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (414).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (415).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (416).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (417).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (418).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (419).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (42).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (420).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (421).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (422).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (423).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (424).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (425).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (426).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (427).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (428).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (429).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (43).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (430).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (431).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (432).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (433).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (434).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (435).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (436).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (437).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (438).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (439).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (44).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (440).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (441).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (442).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (443).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (444).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (445).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (446).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (447).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (448).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (449).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (45).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (450).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (451).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (452).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (453).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (454).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (455).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (456).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (457).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (458).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (459).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (46).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (460).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (461).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (462).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (463).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (464).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (465).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (466).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (467).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (468).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (469).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (47).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (470).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (471).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (472).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (473).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (474).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (475).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (476).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (477).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (478).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (479).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (48).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (480).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (481).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (482).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (483).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (484).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (485).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (486).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (487).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (488).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (489).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (49).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (490).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (491).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (492).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (493).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (494).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (495).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (496).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (497).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (498).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (499).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (5).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (50).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (500).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (501).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (502).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (503).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (504).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (505).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (506).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (507).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (508).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (509).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (51).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (510).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (511).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (512).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (513).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (514).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (515).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (516).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (517).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (518).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (519).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (52).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (520).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (521).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (522).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (523).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (524).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (525).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (526).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (527).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (528).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (529).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (53).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (530).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (531).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (532).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (533).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (534).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (535).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (536).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (537).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (538).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (539).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (54).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (540).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (541).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (542).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (543).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (544).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (545).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (546).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (547).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (548).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (549).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (55).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (550).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (551).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (552).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (553).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (554).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (555).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (556).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (557).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (558).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (559).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (56).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (560).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (57).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (58).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (59).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (6).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (60).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (61).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (62).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (63).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (64).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (65).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (66).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (67).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (68).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (69).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (7).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (70).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (71).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (72).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (73).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (74).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (75).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (76).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (77).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (78).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (79).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (8).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (80).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (81).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (82).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (83).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (84).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (85).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (86).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (87).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (88).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (89).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (9).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (90).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (91).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (92).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (93).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (94).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (95).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (96).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (97).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (98).png
#   inflating: /content/data/Ranjana 64/3 Testing/58/58 (99).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (1).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (10).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (100).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (101).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (102).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (103).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (104).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (105).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (106).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (107).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (108).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (109).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (11).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (110).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (111).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (112).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (113).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (114).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (115).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (116).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (117).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (118).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (119).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (12).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (120).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (121).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (122).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (123).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (124).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (125).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (126).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (127).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (128).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (129).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (13).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (130).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (131).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (132).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (133).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (134).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (135).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (136).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (137).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (138).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (139).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (14).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (140).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (141).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (142).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (143).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (144).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (145).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (146).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (147).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (148).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (149).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (15).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (150).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (151).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (152).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (153).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (154).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (155).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (156).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (157).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (158).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (159).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (16).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (160).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (161).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (162).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (163).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (164).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (165).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (166).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (167).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (168).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (169).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (17).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (170).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (171).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (172).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (173).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (174).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (175).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (176).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (177).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (178).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (179).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (18).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (180).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (181).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (182).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (183).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (184).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (185).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (186).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (187).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (188).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (189).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (19).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (190).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (191).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (192).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (193).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (194).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (195).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (196).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (197).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (198).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (199).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (2).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (20).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (200).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (201).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (202).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (203).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (204).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (205).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (206).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (207).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (208).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (209).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (21).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (210).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (211).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (212).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (213).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (214).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (215).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (216).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (217).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (218).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (219).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (22).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (220).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (221).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (222).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (223).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (224).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (225).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (226).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (227).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (228).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (229).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (23).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (230).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (231).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (232).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (233).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (234).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (235).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (236).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (237).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (238).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (239).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (24).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (240).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (241).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (242).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (243).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (244).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (245).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (246).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (247).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (248).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (249).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (25).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (250).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (251).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (252).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (253).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (254).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (255).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (256).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (257).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (258).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (259).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (26).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (260).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (261).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (262).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (263).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (264).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (265).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (266).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (267).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (268).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (269).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (27).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (270).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (271).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (272).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (273).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (274).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (275).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (276).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (277).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (278).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (279).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (28).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (280).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (281).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (282).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (283).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (284).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (285).png
#   inflating: /content/data/Ranjana 64/3 Testing/59/59 (286).png
# ...
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (378).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (379).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (38).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (380).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (381).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (382).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (383).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (384).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (385).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (386).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (387).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (388).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (389).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (39).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (390).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (391).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (392).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (393).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (394).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (395).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (396).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (397).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (398).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (399).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (4).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (40).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (400).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (401).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (402).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (403).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (404).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (405).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (406).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (407).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (408).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (409).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (41).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (410).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (411).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (412).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (413).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (414).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (415).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (416).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (417).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (418).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (419).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (42).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (420).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (421).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (422).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (423).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (424).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (425).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (426).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (427).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (428).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (429).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (43).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (430).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (431).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (432).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (433).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (434).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (435).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (436).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (437).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (438).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (439).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (44).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (440).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (441).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (442).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (443).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (444).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (445).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (446).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (447).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (448).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (449).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (45).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (450).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (451).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (452).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (453).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (454).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (455).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (456).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (457).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (458).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (459).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (46).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (460).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (461).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (462).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (463).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (464).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (465).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (466).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (467).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (468).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (469).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (47).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (470).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (471).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (472).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (473).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (474).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (475).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (476).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (477).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (478).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (479).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (48).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (480).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (481).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (482).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (483).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (484).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (485).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (486).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (487).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (488).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (489).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (49).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (490).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (491).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (492).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (493).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (494).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (495).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (496).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (497).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (498).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (499).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (5).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (50).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (500).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (501).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (502).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (503).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (504).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (505).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (506).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (507).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (508).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (509).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (51).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (510).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (511).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (512).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (513).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (514).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (515).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (516).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (517).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (518).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (519).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (52).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (520).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (521).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (522).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (523).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (524).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (525).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (526).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (527).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (528).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (529).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (53).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (530).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (531).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (532).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (533).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (534).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (535).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (536).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (537).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (538).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (539).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (54).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (540).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (541).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (542).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (543).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (544).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (545).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (546).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (547).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (548).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (549).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (55).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (550).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (551).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (552).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (553).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (554).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (555).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (556).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (557).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (558).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (559).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (56).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (560).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (57).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (58).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (59).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (6).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (60).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (61).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (62).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (63).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (64).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (65).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (66).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (67).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (68).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (69).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (7).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (70).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (71).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (72).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (73).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (74).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (75).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (76).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (77).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (78).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (79).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (8).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (80).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (81).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (82).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (83).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (84).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (85).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (86).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (87).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (88).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (89).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (9).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (90).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (91).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (92).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (93).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (94).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (95).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (96).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (97).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (98).png
#   inflating: /content/data/Ranjana 64/3 Testing/9/9 (99).png

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import Subset, DataLoader
import numpy as np


# Step 1: Define the transforms for the training and testing data
train_transforms = transforms.Compose([
    transforms.Resize((28, 28)),  # Resize to a common size
    #transforms.Grayscale(num_output_channels=1),
    #transforms.RandomHorizontalFlip(),  # Data augmentation
    transforms.ToTensor(),  # Convert images to PyTorch tensors
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize with ImageNet mean and std
])

test_transforms = transforms.Compose([
    transforms.Resize((28, 28)),  # Resize to a common size
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Step 2: Load the datasets using ImageFolder
train_dataset = datasets.ImageFolder(root='/content/data/Ranjana 64/1 Training', transform=train_transforms)
test_dataset = datasets.ImageFolder(root='/content/data/Ranjana 64/3 Testing', transform=test_transforms)

train_images = []
train_labels = []

# Iterate through the dataset
for img, label in train_dataset:
    train_images.append(img)
    train_labels.append(label)

# Convert lists to tensors
train_images_tensor = torch.stack(train_images)  # Stacks all image tensors
train_labels = torch.tensor(train_labels)  # Converts label list to tensor

# Define weights for the RGB channels
weights = torch.tensor([0.2989, 0.5870, 0.1140]).view(1, 3, 1, 1)

# Ensure the weights tensor is on the same device as the images tensor
if train_images_tensor.is_cuda:
    weights = weights.cuda()

# Convert RGB to grayscale
train_images = (train_images_tensor * weights).sum(dim=1, keepdim=True)
train_images=  train_images.squeeze(1)

# Create a train in TensorDataset
train_dataset = TensorDataset(train_images, train_labels)

# Check the shape of the output
# Check the shapes
print(f"Train Images Tensor: {train_images.shape}")  # Expected: [num_samples, channels, height, width]
print(f"Train Labels Tensor: {train_labels.shape}")  # Expected: [num_samples] # Should be [4250, 28, 28]
print("Train_dataset ",len(train_dataset))


test_images = []
test_labels = []

# Iterate through the dataset
for img, label in test_dataset:
    test_images.append(img)
    test_labels.append(label)

# Convert lists to tensors
test_images_tensor = torch.stack(test_images)  # Stacks all image tensors
test_labels = torch.tensor(test_labels)  # Converts label list to tensor

# Convert RGB to grayscale
test_images = (test_images_tensor * weights).sum(dim=1, keepdim=True)
test_images =  test_images.squeeze(1)

# Check the shape of the output
# Check the shapes
print(f"Test Images Tensor: {test_images.shape}")  # Expected: [num_samples, channels, height, width]
print(f"Test Labels Tensor: {test_labels.shape}")  # Expected: [num_samples] # Should be [850, 28,28]

# Create a TensorDataset
test_dataset = TensorDataset(test_images, test_labels)
print("test_dataset ",len(test_dataset))

# # Example: Iterate over the train_loader
# for images, labels in train_loader:
#     print(images.shape, labels.shape)
#     break  # Break after the first batch to show an example
# Out:
# Train Images Tensor: torch.Size([104160, 28, 28])
# Train Labels Tensor: torch.Size([104160])
# Train_dataset  104160
# Test Images Tensor: torch.Size([34720, 28, 28])
# Test Labels Tensor: torch.Size([34720])
# test_dataset  34720

# %%
# Step : Create the subset dataset for training

total_images = len(train_dataset)
num_select = 2000  # Number of images you want to select to training set
selected_indices = np.random.choice(total_images, num_select, replace=False)
train_dataset = Subset(train_dataset, selected_indices)

# Step : Create the subset dataset for testing

total_images = len(test_dataset)
num_select = 600  # Number of images you want to select to training set
selected_indices = np.random.choice(total_images, num_select, replace=False)
test_dataset = Subset(test_dataset, selected_indices)


batch_size=64
# # Step 3: Create the data loaders to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# train_loader=train_loader.squeeze(1)
# test_loader=test_loader.squeeze(1)

# %%
import matplotlib.pyplot as plt

# Plotting function
def plot_images(images, labels, num_images=5):
  fig, axes = plt.subplots(1, num_images, figsize=(10, 2))
  for i, ax in enumerate(axes):
    ax.imshow(images[i], cmap='gray')
    ax.set_title(f'Label: {labels[i]}')
    ax.axis('on')
  plt.show()

# Display the first 5 images and labels
for features, labels in train_loader:
  plot_images(features, labels, 5)
  break  # Only process the first batch#

# %%
unique_labels = torch.unique(train_labels)
num_unique_labels = len(unique_labels)
print(f"Number of unique labels: {num_unique_labels}")
# Out:
# Number of unique labels: 62

# %%
from torch.utils.data import TensorDataset
from IPython.display import display, clear_output
import time


def plot_images_by_label(dataloader, specific_label, num_images=5):
    count = 0  # Counter to track how many images we have displayed
    plt.figure(figsize=(10, 2))  # Set up the figure size

    for images, labels in dataloader:
        for image, label in zip(images, labels):
            if label.item() == specific_label:  # Check if the label matches
                count += 1
                ax = plt.subplot(1, num_images, count)  # Create a subplot for each image
                ax.imshow(image.squeeze(), cmap='gray')  # Display image, squeeze() is used to remove extra dimensions if any
                ax.title.set_text(f'Label: {label.item()}')
                ax.axis('on')  # Turn off axis

                if count == num_images:  # Only display a specific number of images
                    plt.show()
                    return
# Example usage
# Assuming your DataLoader, images, and labels are properly set up
# Here you call the function with the label you want to display and the number of images

for i in range(2):
  plot_images_by_label(train_loader, specific_label=i, num_images=5)# Call the function with the desired label
  clear_output(wait=True)  # Clear the current output and wait for new output
  time.sleep(0.01)  # Pause for a second to simulate time taken in an iteration

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"    # Get gpu or cpu device for training
print(f"Using {device} device\n")

import torch.nn as nn
import torchvision.transforms.functional as TF
from skimage.feature import hog
#from quantum_circuit_simulator import quantum_circuit


# Define a function to compute HOG features for an image
def compute_hog_features(image):
    features, _ = hog(image, orientations=12, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)

    return features

#=====================================================================================


class QNN(torch.nn.Module):                              # Define model
    def __init__(self, n, L):                            # number of qubits = n, number of quantum layers = L
        super().__init__()

        self.flatten = nn.Flatten()

        angles = torch.empty((L, n), dtype=torch.float64)
        torch.nn.init.uniform_(angles, -0.01, 0.01)
        self.angles = torch.nn.Parameter(angles)                   # it makes angles learnable parameters

        # self.fc1 = nn.Linear(1024, 1024)
        # self.fc2 = nn.Linear(784,512)
        # self.fc3 = nn.Linear(512, 1024)

        self.linear1 = nn.Linear(2**n, 256)                          # classical linear layer
        self.linear2 = nn.Linear(256,62)                          # classical linear layer


    def forward(self, x):
        #x = F.pad(x, (2 ,2, 2, 2), "constant", 0)                  # (left, right, top, bottom) padding
        x_projection = torch.sum(x, dim=1).to(device)  # Calculate x-axis projection
        #x_projection = x_projection / torch.norm(x_projection, p=1)
        #print("x projection ",x_projection.shape)
        y_projection = torch.sum(x, dim=2).to(device)  # Calculate x-axis projection
        #print("y projection ",y_projection.shape)
        #y_projection = y_projection / torch.norm(y_projection, p=1)
        #angle projection
        rotated_images1 = TF.rotate(x,30).to(device)
        rotated_images2 = TF.rotate(x,45).to(device)
        rotated_images3 = TF.rotate(x,60).to(device)

        #rotated projections
        rotated_projection1=torch.sum(rotated_images1, dim=2).to(device)
        rotated_projection2=torch.sum(rotated_images2, dim=2).to(device)
        rotated_projection3=torch.sum(rotated_images3, dim=2).to(device)

        #rotated_images = torch.sum(torch.stack([TF.rotate(img, angle) for img in inputs]))
        x_image=x.cpu().numpy()
        hog_features = [compute_hog_features(np.squeeze(image)) for image in x_image]
        hog_features_tensor = torch.tensor(np.array(hog_features), dtype=torch.float32).to(device)
        #print(hog_features_tensor.shape)

        x = self.flatten(x)
        x = x[:, :-92]

        # print("sizes ",x.shape, y_projection.shape, rotated_projection1.shape,rotated_projection2.shape,
        #      rotated_projection3.shape,hog_features_tensor.shape)

        combined_projection=torch.cat((x,x_projection,y_projection, rotated_projection1,rotated_projection2,rotated_projection3,#rotated_projection4.squeeze(),rotated_projection5.squeeze(),rotated_projection6.squeeze(),
                                       hog_features_tensor), dim=1)
        #print(x.shape, " ",hog_features_tensor.shape)
        #torch.zeros(x.shape[0],100).to(device)
        #print("combined ", combined_projection.shape)
        #x = self.flatten(x)
        combined_projection /= torch.linalg.norm(x.clone(), ord=2, dim=1, keepdim=True)   # L2 normalization to change x --> |x⟩

        # combined_projection = torch.sigmoid(self.fc1(combined_projection))
        # x1 = torch.sigmoid(self.fc2(x1))
        # x1 = torch.sigmoid(self.fc3(x1))

        '''initializing parameterized quantum circuits (PQC)'''

        qc = quantum_circuit(num_qubits = n, state_vector = combined_projection.T)   # each column is a feature-vector of an example
        for l in range(L):
            qc.Ry_layer(self.angles[l].to(torch.cfloat))           # rotation part of lth quantum layer
            qc.cx_linear_layer()                                   # entangling part of lth quantum layer

        'after passing through the PQC, measurement on the output-ket in the computational basis'
        x = torch.real(qc.probabilities())               # each column is a probabilities-vector for an example
                                                         # x.shape = (dim, batch size)

        #print(torch.sum(x, dim=0))                      # to see whether probabilities add up to 1 or not

        x = self.linear1(x.T)                            # x.shape = (batch size, 10),  classical linear layer
        x= self.linear2(x)
        return x
# Out:
# Using cuda device

# %%
def performance_estimate(dataset, model, loss_fn, train_or_test):
    '''this function computes accuracy and loss of a model on the training or test set'''
    data_size = len(dataset)

    dataloader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True)
    num_batches = len(dataloader)

    model.eval()
    loss, accuracy = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            accuracy += (pred.argmax(1) == y).sum().item()
            loss += loss_fn(pred, y).item()
    accuracy /= data_size                                            # accuracy lies in the interval [0, 1]
    loss /= num_batches
    print(f"{train_or_test} accuracy: {round(accuracy, 3)},  {train_or_test} loss: {round(loss,3)}")
    return accuracy, loss




def one_epoch(model, loss_fn, optimizer, train_dataset, test_dataset, batch_size):

    A_train, L_train, A_test, L_test = [], [], [], []

    dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        out = model(X)                             # Perform a single forward pass
        loss = loss_fn(out, y)

        optimizer.zero_grad()                      # Clear gradients
        loss.backward()                            # Derive gradients, backpropagation
        optimizer.step()                           # Update parameters based on gradients


        if batch % batch_size == 0:
            #As training progress, computing and appending loss and accuracy of the model on train and test set
            accuracy_train, loss_train = performance_estimate(train_dataset, model, loss_fn, 'train')
            accuracy_test, loss_test = performance_estimate(test_dataset, model, loss_fn, 'test ')
            print()

            A_train.append(accuracy_train)
            L_train.append(loss_train)
            A_test.append(accuracy_test)
            L_test.append(loss_test)

            #print(f"train loss: {round(loss,3)}")

    return A_train, L_train, A_test, L_test



def training(train_dataset, test_dataset, batch_size, n, L, lr_, weight_decay_, epochs):

    model = QNN(n=n, L=L).to(device)
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr_, weight_decay=weight_decay_)

    A_Train, L_Train, A_Test, L_Test = [], [], [], []
    for t in range(epochs):
        print(f"Epoch {t+1} ---------------------------------- \n")
        #As training progress, computing and appending loss and accuracy of the model on train and test set
        A_train, L_train, A_test, L_test = one_epoch(model, loss_fn, optimizer, train_dataset, test_dataset, batch_size)
        A_Train += A_train
        L_Train += L_train
        A_Test += A_test
        L_Test += L_test

        #accuracy, loss = performance_estimate(test_dataset, model, loss_fn, 'test ')

    model_state_dict = model.state_dict()           # for saving or loading the trained model

    return A_Train, L_Train, A_Test, L_Test, model_state_dict

# %%
# %%time

n = 10
dim = 2**n              # dimension of the n-qubit Hilbert space
L = 3

n_angs = n*L

print("number of qubits = ", n)
print("number of quantum layers = ", L)
print(f"number of angles (learnable parameters of quantum circuit) = {n_angs}\n ")

#--------------------------------------------------------------------------------------


batch_size = 64
print(f'batch_size = {batch_size}\n')


#----------------------------------------------------------------------------------


A_Train, L_Train, A_Test, L_Test, model_state_dict = training(train_dataset, test_dataset, batch_size=batch_size, n=n, L=L,
                                                              lr_=0.01/10, weight_decay_=1e-10, epochs=100)


print(f' ~~~~~ training is done ~~~~~\n')
# Out:
# number of qubits =  10
# number of quantum layers =  3
# number of angles (learnable parameters of quantum circuit) = 30
#
# batch_size = 64
#
# Epoch 1 ----------------------------------
#
# train accuracy: 0.025,  train loss: 4.127
# test  accuracy: 0.02,  test  loss: 4.129
#
# Epoch 2 ----------------------------------
#
# train accuracy: 0.038,  train loss: 3.888
# test  accuracy: 0.018,  test  loss: 3.961
#
# Epoch 3 ----------------------------------
#
# train accuracy: 0.209,  train loss: 3.511
# test  accuracy: 0.12,  test  loss: 3.625
#
# Epoch 4 ----------------------------------
#
# train accuracy: 0.281,  train loss: 3.142
# test  accuracy: 0.16,  test  loss: 3.375
#
# Epoch 5 ----------------------------------
#
# train accuracy: 0.351,  train loss: 2.821
# test  accuracy: 0.202,  test  loss: 3.138
#
# Epoch 6 ----------------------------------
#
# train accuracy: 0.418,  train loss: 2.529
# test  accuracy: 0.228,  test  loss: 2.951
#
# Epoch 7 ----------------------------------
#
# train accuracy: 0.474,  train loss: 2.302
# test  accuracy: 0.275,  test  loss: 2.763
#
# Epoch 8 ----------------------------------
#
# train accuracy: 0.519,  train loss: 2.086
# test  accuracy: 0.32,  test  loss: 2.584
#
# Epoch 9 ----------------------------------
#
# train accuracy: 0.536,  train loss: 1.921
# test  accuracy: 0.335,  test  loss: 2.482
#
# Epoch 10 ----------------------------------
#
# train accuracy: 0.582,  train loss: 1.758
# test  accuracy: 0.377,  test  loss: 2.412
#
# Epoch 11 ----------------------------------
#
# train accuracy: 0.617,  train loss: 1.647
# test  accuracy: 0.402,  test  loss: 2.368
#
# Epoch 12 ----------------------------------
#
# train accuracy: 0.636,  train loss: 1.537
# test  accuracy: 0.382,  test  loss: 2.266
#
# Epoch 13 ----------------------------------
#
# train accuracy: 0.653,  train loss: 1.424
# test  accuracy: 0.423,  test  loss: 2.175
#
# Epoch 14 ----------------------------------
#
# train accuracy: 0.669,  train loss: 1.361
# test  accuracy: 0.413,  test  loss: 2.189
#
# Epoch 15 ----------------------------------
#
# train accuracy: 0.693,  train loss: 1.291
# test  accuracy: 0.42,  test  loss: 2.202
#
# Epoch 16 ----------------------------------
#
# train accuracy: 0.701,  train loss: 1.237
# test  accuracy: 0.427,  test  loss: 2.131
#
# Epoch 17 ----------------------------------
#
# train accuracy: 0.712,  train loss: 1.156
# test  accuracy: 0.43,  test  loss: 2.175
#
# Epoch 18 ----------------------------------
#
# train accuracy: 0.733,  train loss: 1.109
# test  accuracy: 0.437,  test  loss: 2.042
#
# Epoch 19 ----------------------------------
#
# train accuracy: 0.741,  train loss: 1.064
# test  accuracy: 0.458,  test  loss: 2.078
#
# Epoch 20 ----------------------------------
#
# train accuracy: 0.756,  train loss: 1.01
# test  accuracy: 0.453,  test  loss: 2.107
#
# Epoch 21 ----------------------------------
#
# train accuracy: 0.765,  train loss: 0.97
# test  accuracy: 0.453,  test  loss: 2.019
#
# Epoch 22 ----------------------------------
#
# train accuracy: 0.771,  train loss: 0.934
# test  accuracy: 0.445,  test  loss: 2.114
#
# Epoch 23 ----------------------------------
#
# train accuracy: 0.784,  train loss: 0.888
# test  accuracy: 0.458,  test  loss: 2.053
#
# Epoch 24 ----------------------------------
#
# train accuracy: 0.801,  train loss: 0.852
# test  accuracy: 0.457,  test  loss: 2.025
#
# Epoch 25 ----------------------------------
#
# train accuracy: 0.805,  train loss: 0.828
# test  accuracy: 0.47,  test  loss: 2.042
#
# Epoch 26 ----------------------------------
#
# train accuracy: 0.811,  train loss: 0.793
# test  accuracy: 0.467,  test  loss: 2.052
#
# Epoch 27 ----------------------------------
#
# train accuracy: 0.819,  train loss: 0.77
# test  accuracy: 0.47,  test  loss: 2.015
#
# Epoch 28 ----------------------------------
#
# train accuracy: 0.822,  train loss: 0.727
# test  accuracy: 0.463,  test  loss: 2.062
#
# Epoch 29 ----------------------------------
#
# train accuracy: 0.828,  train loss: 0.715
# test  accuracy: 0.462,  test  loss: 2.071
#
# Epoch 30 ----------------------------------
#
# train accuracy: 0.836,  train loss: 0.68
# test  accuracy: 0.468,  test  loss: 2.009
#
# Epoch 31 ----------------------------------
#
# train accuracy: 0.855,  train loss: 0.661
# test  accuracy: 0.47,  test  loss: 2.048
#
# Epoch 32 ----------------------------------
#
# train accuracy: 0.856,  train loss: 0.633
# test  accuracy: 0.458,  test  loss: 2.056
#
# Epoch 33 ----------------------------------
#
# train accuracy: 0.863,  train loss: 0.613
# test  accuracy: 0.477,  test  loss: 2.048
#
# Epoch 34 ----------------------------------
#
# train accuracy: 0.866,  train loss: 0.582
# test  accuracy: 0.477,  test  loss: 2.071
#
# Epoch 35 ----------------------------------
#
# train accuracy: 0.872,  train loss: 0.557
# test  accuracy: 0.465,  test  loss: 2.124
#
# Epoch 36 ----------------------------------
#
# train accuracy: 0.877,  train loss: 0.547
# test  accuracy: 0.46,  test  loss: 2.118
#
# Epoch 37 ----------------------------------
#
# train accuracy: 0.882,  train loss: 0.521
# test  accuracy: 0.468,  test  loss: 2.071
#
# Epoch 38 ----------------------------------
#
# train accuracy: 0.887,  train loss: 0.505
# test  accuracy: 0.448,  test  loss: 2.066
#
# Epoch 39 ----------------------------------
#
# train accuracy: 0.896,  train loss: 0.485
# test  accuracy: 0.457,  test  loss: 2.03
#
# Epoch 40 ----------------------------------
#
# train accuracy: 0.898,  train loss: 0.483
# test  accuracy: 0.463,  test  loss: 2.061
#
# Epoch 41 ----------------------------------
#
# train accuracy: 0.904,  train loss: 0.453
# test  accuracy: 0.463,  test  loss: 2.109
#
# Epoch 42 ----------------------------------
#
# train accuracy: 0.909,  train loss: 0.433
# test  accuracy: 0.46,  test  loss: 2.136
#
# Epoch 43 ----------------------------------
#
# train accuracy: 0.908,  train loss: 0.421
# test  accuracy: 0.442,  test  loss: 2.153
#
# Epoch 44 ----------------------------------
#
# train accuracy: 0.927,  train loss: 0.397
# test  accuracy: 0.455,  test  loss: 2.108
#
# Epoch 45 ----------------------------------
#
# train accuracy: 0.93,  train loss: 0.387
# test  accuracy: 0.462,  test  loss: 2.193
#
# Epoch 46 ----------------------------------
#
# train accuracy: 0.934,  train loss: 0.378
# test  accuracy: 0.453,  test  loss: 2.238
#
# Epoch 47 ----------------------------------
#
# train accuracy: 0.934,  train loss: 0.363
# test  accuracy: 0.463,  test  loss: 2.234
#
# Epoch 48 ----------------------------------
#
# train accuracy: 0.94,  train loss: 0.348
# test  accuracy: 0.472,  test  loss: 2.24
#
# Epoch 49 ----------------------------------
#
# train accuracy: 0.943,  train loss: 0.33
# test  accuracy: 0.463,  test  loss: 2.176
#
# Epoch 50 ----------------------------------
#
# train accuracy: 0.944,  train loss: 0.324
# test  accuracy: 0.478,  test  loss: 2.22
#
# Epoch 51 ----------------------------------
#
# train accuracy: 0.95,  train loss: 0.309
# test  accuracy: 0.465,  test  loss: 2.192
#
# Epoch 52 ----------------------------------
#
# train accuracy: 0.951,  train loss: 0.301
# test  accuracy: 0.448,  test  loss: 2.208
#
# Epoch 53 ----------------------------------
#
# train accuracy: 0.956,  train loss: 0.294
# test  accuracy: 0.453,  test  loss: 2.279
#
# Epoch 54 ----------------------------------
#
# train accuracy: 0.96,  train loss: 0.274
# test  accuracy: 0.462,  test  loss: 2.261
#
# Epoch 55 ----------------------------------
#
# train accuracy: 0.956,  train loss: 0.282
# test  accuracy: 0.457,  test  loss: 2.303
#
# Epoch 56 ----------------------------------
#
# train accuracy: 0.971,  train loss: 0.254
# test  accuracy: 0.462,  test  loss: 2.301
#
# Epoch 57 ----------------------------------
#
# train accuracy: 0.975,  train loss: 0.248
# test  accuracy: 0.453,  test  loss: 2.28
#
# Epoch 58 ----------------------------------
#
# train accuracy: 0.973,  train loss: 0.238
# test  accuracy: 0.46,  test  loss: 2.329
#
# Epoch 59 ----------------------------------
#
# train accuracy: 0.972,  train loss: 0.234
# test  accuracy: 0.457,  test  loss: 2.39
#
# Epoch 60 ----------------------------------
#
# train accuracy: 0.97,  train loss: 0.232
# test  accuracy: 0.452,  test  loss: 2.326
#
# Epoch 61 ----------------------------------
#
# train accuracy: 0.972,  train loss: 0.221
# test  accuracy: 0.445,  test  loss: 2.426
#
# Epoch 62 ----------------------------------
#
# train accuracy: 0.98,  train loss: 0.206
# test  accuracy: 0.458,  test  loss: 2.502
#
# Epoch 63 ----------------------------------
#
# train accuracy: 0.979,  train loss: 0.203
# test  accuracy: 0.45,  test  loss: 2.349
#
# Epoch 64 ----------------------------------
#
# train accuracy: 0.986,  train loss: 0.19
# test  accuracy: 0.458,  test  loss: 2.404
#
# Epoch 65 ----------------------------------
#
# train accuracy: 0.988,  train loss: 0.182
# test  accuracy: 0.46,  test  loss: 2.449
#
# Epoch 66 ----------------------------------
#
# train accuracy: 0.982,  train loss: 0.186
# test  accuracy: 0.458,  test  loss: 2.432
#
# Epoch 67 ----------------------------------
#
# train accuracy: 0.992,  train loss: 0.168
# test  accuracy: 0.457,  test  loss: 2.471
#
# Epoch 68 ----------------------------------
#
# train accuracy: 0.994,  train loss: 0.161
# test  accuracy: 0.462,  test  loss: 2.458
#
# Epoch 69 ----------------------------------
#
# train accuracy: 0.993,  train loss: 0.16
# test  accuracy: 0.465,  test  loss: 2.43
#
# Epoch 70 ----------------------------------
#
# train accuracy: 0.988,  train loss: 0.16
# test  accuracy: 0.458,  test  loss: 2.556
#
# Epoch 71 ----------------------------------
#
# train accuracy: 0.993,  train loss: 0.152
# test  accuracy: 0.467,  test  loss: 2.496
#
# Epoch 72 ----------------------------------
#
# train accuracy: 0.991,  train loss: 0.145
# test  accuracy: 0.463,  test  loss: 2.582
#
# Epoch 73 ----------------------------------
#
# train accuracy: 0.994,  train loss: 0.138
# test  accuracy: 0.467,  test  loss: 2.524
#
# Epoch 74 ----------------------------------
#
# train accuracy: 0.995,  train loss: 0.131
# test  accuracy: 0.458,  test  loss: 2.614
#
# Epoch 75 ----------------------------------
#
# train accuracy: 0.994,  train loss: 0.131
# test  accuracy: 0.467,  test  loss: 2.578
#
# Epoch 76 ----------------------------------
#
# train accuracy: 0.996,  train loss: 0.126
# test  accuracy: 0.47,  test  loss: 2.557
#
# Epoch 77 ----------------------------------
#
# train accuracy: 0.996,  train loss: 0.12
# test  accuracy: 0.453,  test  loss: 2.64
#
# Epoch 78 ----------------------------------
#
# train accuracy: 0.997,  train loss: 0.119
# test  accuracy: 0.468,  test  loss: 2.646
#
# Epoch 79 ----------------------------------
#
# train accuracy: 0.995,  train loss: 0.109
# test  accuracy: 0.457,  test  loss: 2.635
#
# Epoch 80 ----------------------------------
#
# train accuracy: 0.997,  train loss: 0.111
# test  accuracy: 0.45,  test  loss: 2.682
#
# Epoch 81 ----------------------------------
#
# train accuracy: 0.998,  train loss: 0.103
# test  accuracy: 0.452,  test  loss: 2.644
#
# Epoch 82 ----------------------------------
#
# train accuracy: 0.998,  train loss: 0.103
# test  accuracy: 0.468,  test  loss: 2.634
#
# Epoch 83 ----------------------------------
#
# train accuracy: 0.998,  train loss: 0.096
# test  accuracy: 0.462,  test  loss: 2.64
#
# Epoch 84 ----------------------------------
#
# train accuracy: 0.996,  train loss: 0.103
# test  accuracy: 0.457,  test  loss: 2.745
#
# Epoch 85 ----------------------------------
#
# train accuracy: 0.998,  train loss: 0.092
# test  accuracy: 0.452,  test  loss: 2.833
#
# Epoch 86 ----------------------------------
#
# train accuracy: 0.998,  train loss: 0.09
# test  accuracy: 0.46,  test  loss: 2.768
#
# Epoch 87 ----------------------------------
#
# train accuracy: 0.997,  train loss: 0.09
# test  accuracy: 0.455,  test  loss: 2.797
#
# Epoch 88 ----------------------------------
#
# train accuracy: 0.999,  train loss: 0.081
# test  accuracy: 0.462,  test  loss: 2.766
#
# Epoch 89 ----------------------------------
#
# train accuracy: 0.999,  train loss: 0.079
# test  accuracy: 0.453,  test  loss: 2.82
#
# Epoch 90 ----------------------------------
#
# train accuracy: 0.999,  train loss: 0.079
# test  accuracy: 0.46,  test  loss: 2.817
#
# Epoch 91 ----------------------------------
#
# train accuracy: 0.999,  train loss: 0.076
# test  accuracy: 0.45,  test  loss: 2.916
#
# Epoch 92 ----------------------------------
#
# train accuracy: 0.995,  train loss: 0.086
# test  accuracy: 0.442,  test  loss: 2.886
#
# Epoch 93 ----------------------------------
#
# train accuracy: 0.999,  train loss: 0.075
# test  accuracy: 0.455,  test  loss: 2.882
#
# Epoch 94 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.069
# test  accuracy: 0.462,  test  loss: 2.886
#
# Epoch 95 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.067
# test  accuracy: 0.455,  test  loss: 2.845
#
# Epoch 96 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.064
# test  accuracy: 0.457,  test  loss: 2.881
#
# Epoch 97 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.063
# test  accuracy: 0.463,  test  loss: 2.79
#
# Epoch 98 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.062
# test  accuracy: 0.448,  test  loss: 2.899
#
# Epoch 99 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.06
# test  accuracy: 0.467,  test  loss: 2.835
#
# Epoch 100 ----------------------------------
#
# train accuracy: 1.0,  train loss: 0.058
# test  accuracy: 0.46,  test  loss: 2.914
#
#  ~~~~~ training is done ~~~~~
#
# CPU times: user 17min 50s, sys: 10.1 s, total: 18min 1s
# Wall time: 18min 4s

# %%
plt.plot(A_Train, label='train set')
plt.plot(A_Test, label='test set')
plt.ylabel('accuracy')
plt.legend()
plt.show()

plt.plot(L_Train, label='train set')
plt.plot(L_Test, label='test set')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
idx = np.random.choice(len(test_dataset))

x = test_dataset[idx][0]
print(f'x of {x.shape} :')
plt.imshow(x, cmap='gray')
plt.show()

print(f'true label = y = {test_dataset[idx][1]}\n')


out_ = model(x) #.detach().flatten()
prob = F.softmax(out_, dim=0)
pred = prob.argmax().item()
print(f'predicted label = {pred}\n')

plt.stem(np.arange(10), prob)
plt.ylabel('probability')
plt.xlabel('class labels')
plt.show()
# Out:
# x of torch.Size([28, 28]) :
# true label = y = 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e9d32e61273f> in <cell line: 11>()
#       9
#      10
# ---> 11 out_ = model(x) #.detach().flatten()
#      12 prob = F.softmax(out_, dim=0)
#      13 pred = prob.argmax().item()
#
# NameError: name 'model' is not defined

# %%
2048-1896
